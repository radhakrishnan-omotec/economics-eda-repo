# %% [markdown]
# <a href="https://colab.research.google.com/github/radhakrishnan-omotec/economics-eda-repo/blob/main/Project_5_Mental_Health_Factors_EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Factors Contributing to Economic Burden in Mental Health Services: A Data-Driven Analysis

# %% [markdown]
# ## Sahaj Sohi

# %%
# !git clone https://github.com/radhakrishnan-omotec/economics-eda-repo.git
# Out:
# Cloning into 'economics-eda-repo'...
# remote: Enumerating objects: 24, done.
# remote: Counting objects: 100% (24/24), done.
# remote: Compressing objects: 100% (23/23), done.
# remote: Total 24 (delta 8), reused 0 (delta 0), pack-reused 0
# Receiving objects: 100% (24/24), 709.55 KiB | 3.22 MiB/s, done.
# Resolving deltas: 100% (8/8), done.

# %% [markdown]
# #### ABSTRACT : This exploratory data analysis (EDA) delves into the Factors Contributing to Economic Burden in Mental Health Services:
# Using Generated Factors for the "Economic Burden in Mental Health Services"

# %% [markdown]
# #### 1) Importing the necessary python libraries

# %%
import pandas as pd

# %% [markdown]
# #### 2) Reading the CSV file

# %%
test_df = pd.read_csv("/content/economics-eda-repo/Economic Burden Mental Health Form.csv")
test_df.head()
# Out:
#    Sr No.  Email Name of the Participant  Designation Age Group   \
# 0       1  sahaj                    sahja       sahaj      25-34
#
#   Does limited insurance coverage have an impact on individuals seeking mental health services?  \
# 0                                                Yes
#
#   Does stigma and discrimination contribute to the economic burden in mental health services?  \
# 0                                                Yes
#
#    Do high treatment costs have consequences on mental health services?  \
# 0                                                Yes
#
#   Do workplace barriers contribute to the economic burden in mental health services?  \
# 0                                                Yes
#
#   Does a shortage of mental health professionals have an impact on mental health services?  \
# 0                                                Yes
#
#    ...  \
# 0  ...
#
# ...

# %%
test_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1 entries, 0 to 0
# Data columns (total 25 columns):
#  #   Column                                                                                                        Non-Null Count  Dtype
# ---  ------                                                                                                        --------------  -----
#  0   Sr No.                                                                                                        1 non-null      int64
#  1   Email                                                                                                         1 non-null      object
#  2   Name of the Participant                                                                                       1 non-null      object
#  3   Designation                                                                                                   1 non-null      object
# ...

# %%
test_df.describe()
# Out:
#        Sr No.
# count     1.0
# mean      1.0
# std       NaN
# min       1.0
# 25%       1.0
# 50%       1.0
# 75%       1.0
# max       1.0
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['Sr No.'].plot(kind='hist', bins=20, title='Sr No.')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_1['Sr No.'].plot(kind='line', figsize=(8, 4), title='Sr No.')
# plt.gca().spines[['top', 'right']].set_visible(False)

# %% [markdown]
# #### STEP : Preprocessing Dataset

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le_Age_group = LabelEncoder()
le_Designation = LabelEncoder()
le_Q1 = LabelEncoder()
le_Q2 = LabelEncoder()
le_Q3 = LabelEncoder()
le_Q4 = LabelEncoder()
le_Q5 = LabelEncoder()
le_Q6 = LabelEncoder()
le_Q7 = LabelEncoder()
le_Q8 = LabelEncoder()
le_Q9 = LabelEncoder()
le_Q10 = LabelEncoder()
le_Q11 = LabelEncoder()
le_Q12 = LabelEncoder()
le_Q13 = LabelEncoder()
le_Q14 = LabelEncoder()
le_Q15 = LabelEncoder()
le_Q16 = LabelEncoder()
le_Q17 = LabelEncoder()
le_Q18 = LabelEncoder()
le_Q19 = LabelEncoder()
le_Q20 = LabelEncoder()

# %%
test_df['Designation_new'] = le_Designation.fit_transform(test_df['Designation'])

# %%
test_df.head()
# Out:
#    Sr No.  Email Name of the Participant  Designation Age Group   \
# 0       1  sahaj                    sahja       sahaj      25-34
#
#   Does limited insurance coverage have an impact on individuals seeking mental health services?  \
# 0                                                Yes
#
#   Does stigma and discrimination contribute to the economic burden in mental health services?  \
# 0                                                Yes
#
#    Do high treatment costs have consequences on mental health services?  \
# 0                                                Yes
#
#   Do workplace barriers contribute to the economic burden in mental health services?  \
# 0                                                Yes
#
#   Does a shortage of mental health professionals have an impact on mental health services?  \
# 0                                                Yes
#
#    ...  \
# 0  ...
#
#   Do some aspects of insurance plans restricts access to mental health services?  \
# ...

# %% [markdown]
# #### STEP : Age Range Preprocessing

# %% [markdown]
# Age Range <br>
# 18 - 24 ( Range 0) <br>
# 25 - 34 ( Range 1) <br>
# 35 - 44 ( Range 2) <br>
# 45 - 54 ( Range 3) <br>
# 55 - 64 ( Range 4) <br>
# 55 and above ( Range 5) <br>

# %%
# Define the age ranges and labels
age_ranges = ["18 - 24", "25 - 34", "35 - 44", "45 - 54", "55 and above"]
age_labels = [0, 1, 2, 3, 4]

# Map age_range values to age_labels
age_mapping = dict(zip(age_ranges, age_labels))
print(age_mapping)
print()
print(test_df["Age Group "])
test_df['Age_group_new'] = test_df['Age Group '].map(age_mapping)

# Display the DataFrame with age labels
print(test_df['Age_group_new'])
# Out:
# {'18 - 24': 0, '25 - 34': 1, '35 - 44': 2, '45 - 54': 3, '55 and above': 4}
#
# 0    25-34
# Name: Age Group , dtype: object
# 0   NaN
# Name: Age_group_new, dtype: float64

# %%
test_df.head()
# Out:
#    Sr No.  Email Name of the Participant  Designation Age Group   \
# 0       1  sahaj                    sahja       sahaj      25-34
#
#   Does limited insurance coverage have an impact on individuals seeking mental health services?  \
# 0                                                Yes
#
#   Does stigma and discrimination contribute to the economic burden in mental health services?  \
# 0                                                Yes
#
#    Do high treatment costs have consequences on mental health services?  \
# 0                                                Yes
#
#   Do workplace barriers contribute to the economic burden in mental health services?  \
# 0                                                Yes
#
#   Does a shortage of mental health professionals have an impact on mental health services?  \
# 0                                                Yes
#
#    ...  \
# 0  ...
#
# ...
