# %% [markdown]
# <a href="https://colab.research.google.com/github/radhakrishnan-omotec/economics-eda-repo/blob/main/Project_11_Mental_Health_Factors_EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Factors Contributing to Economic Burden in Mental Health Services: A Data-Driven Analysis

# %% [markdown]
# ## Sahaj Sohi

# %%
# !git clone https://github.com/radhakrishnan-omotec/economics-eda-repo.git
# Out:
# Cloning into 'economics-eda-repo'...
# remote: Enumerating objects: 66, done.
# remote: Counting objects: 100% (66/66), done.
# remote: Compressing objects: 100% (65/65), done.
# remote: Total 66 (delta 34), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (66/66), 2.18 MiB | 3.60 MiB/s, done.
# Resolving deltas: 100% (34/34), done.

# %% [markdown]
# #### ABSTRACT : This exploratory data analysis (EDA) delves into the Factors Contributing to Economic Burden in Mental Health Services:
# Using Generated Factors for the "Economic Burden in Mental Health Services"

# %% [markdown]
# #### 1) Importing the necessary python libraries

# %%
import pandas as pd

# %% [markdown]
# #### 2) Reading the CSV file

# %%
test_df = pd.read_csv("/content/economics-eda-repo/Input_CSV_File.csv")
test_df.head()
# Out:
#    Sr No. Name of the Participant            Designation  \
# 0       1          Palwinder Singh    Corporate employee
# 1       2            Jaideep Pawar         Self-Business
# 2       3         Dr Vinita Goyle   Medical professional
# 3       4           SATISH THANAGE    Corporate employee
# 4       5             Laxmi Pawar          Self-Business
#
#                                     Economic status     Age Group   \
# 0  Upper Income households (more than 30,00,000 I...       45 - 54
# 1  Middle Income households (1,25,000-30,00,000 I...       45 - 54
# 2  Middle Income households (1,25,000-30,00,000 I...  55 and above
# 3  Upper Income households (more than 30,00,000 I...       45 - 54
# 4  Upper Income households (more than 30,00,000 I...         35-44
#
#   1. Does limited insurance coverage have an impact on individuals seeking mental health services?  \
# 0                                                Yes
# 1                                           Not Sure
# ...

# %%
test_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 54 entries, 0 to 53
# Data columns (total 23 columns):
#  #   Column                                                                                                                       Non-Null Count  Dtype
# ---  ------                                                                                                                       --------------  -----
#  0   Sr No.                                                                                                                       54 non-null     int64
#  1   Name of the Participant                                                                                                      54 non-null     object
#  2   Designation                                                                                                                  54 non-null     object
# ...

# %%
test_df.describe()
# Out:
#           Sr No.
# count  54.000000
# mean   27.500000
# std    15.732133
# min     1.000000
# 25%    14.250000
# 50%    27.500000
# 75%    40.750000
# max    54.000000

# %% [markdown]
# #### STEP : Preprocessing Dataset

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le_Age_group = LabelEncoder()
le_Designation = LabelEncoder()
le_Economic_status = LabelEncoder()
le_Q1 = LabelEncoder()
le_Q2 = LabelEncoder()
le_Q3 = LabelEncoder()
le_Q4 = LabelEncoder()
le_Q5 = LabelEncoder()
le_Q6 = LabelEncoder()
le_Q7 = LabelEncoder()
le_Q8 = LabelEncoder()
le_Q9 = LabelEncoder()
le_Q10 = LabelEncoder()
le_Q11 = LabelEncoder()
le_Q12 = LabelEncoder()
le_Q13 = LabelEncoder()
le_Q14 = LabelEncoder()
le_Q15 = LabelEncoder()
le_Q16 = LabelEncoder()
le_Q17 = LabelEncoder()
le_Q18 = LabelEncoder()

# %%
test_df['Designation_new'] = le_Designation.fit_transform(test_df['Designation'])

# %%
test_df.head()
# Out:
#    Sr No. Name of the Participant            Designation  \
# 0       1          Palwinder Singh    Corporate employee
# 1       2            Jaideep Pawar         Self-Business
# 2       3         Dr Vinita Goyle   Medical professional
# 3       4           SATISH THANAGE    Corporate employee
# 4       5             Laxmi Pawar          Self-Business
#
#                                     Economic status     Age Group   \
# 0  Upper Income households (more than 30,00,000 I...       45 - 54
# 1  Middle Income households (1,25,000-30,00,000 I...       45 - 54
# 2  Middle Income households (1,25,000-30,00,000 I...  55 and above
# 3  Upper Income households (more than 30,00,000 I...       45 - 54
# 4  Upper Income households (more than 30,00,000 I...         35-44
#
#   1. Does limited insurance coverage have an impact on individuals seeking mental health services?  \
# 0                                                Yes
# 1                                           Not Sure
# ...

# %% [markdown]
# #### STEP : Age Range Preprocessing

# %% [markdown]
# Age Range <br>
# 18 - 24 ( Range 0) <br>
# 25 - 34 ( Range 1) <br>
# 35 - 44 ( Range 2) <br>
# 45 - 54 ( Range 3) <br>
# 55 - 64 ( Range 4) <br>
# 55 and above ( Range 5) <br>

# %%
# Define the age ranges and labels
age_ranges = ["18 - 24", "25-34", "35-44", "45 - 54", "55 and above"]
age_labels = [0, 1, 2, 3, 4]

# Map age_range values to age_labels
age_mapping = dict(zip(age_ranges, age_labels))
print(age_mapping)
print()
print(test_df["Age Group "])
test_df['Age_group_new'] = test_df['Age Group '].map(age_mapping)

# Display the DataFrame with age labels
print(test_df['Age_group_new'])
# Out:
# {'18 - 24': 0, '25-34': 1, '35-44': 2, '45 - 54': 3, '55 and above': 4}
#
# 0          45 - 54
# 1          45 - 54
# 2     55 and above
# 3          45 - 54
# 4            35-44
# 5          45 - 54
# 6     55 and above
# 7            25-34
# 8     55 and above
# 9          45 - 54
# 10    55 and above
# 11           35-44
# 12           35-44
# 13         45 - 54
# 14         45 - 54
# 15           25-34
# 16         45 - 54
# 17           25-34
# 18           25-34
# 19         45 - 54
# 20           25-34
# 21           35-44
# 22           25-34
# 23           25-34
# 24         45 - 54
# 25           35-44
# 26         45 - 54
# 27           35-44
# 28    55 and above
# 29         45 - 54
# 30    55 and above
# 31         45 - 54
# 32         45 - 54
# 33           35-44
# 34           35-44
# 35           35-44
# 36         45 - 54
# 37         45 - 54
# 38           25-34
# 39         45 - 54
# 40           25-34
# 41           35-44
# 42         45 - 54
# 43           35-44
# ...

# %%
test_df.head(54)
# Out:
#     Sr No.          Name of the Participant            Designation  \
# 0        1                   Palwinder Singh    Corporate employee
# 1        2                     Jaideep Pawar         Self-Business
# 2        3                  Dr Vinita Goyle   Medical professional
# 3        4                    SATISH THANAGE    Corporate employee
# 4        5                      Laxmi Pawar          Self-Business
# 5        6                 Rajesh Srinivasan    Corporate employee
# 6        7                        Arokiaraj                  Other
# 7        8                            ankush   Teaching profession
# 8        9                    Samita  Sarkar                 Other
# 9       10                    Vishal Murarka         Self-Business
# 10      11                    Neelam Pandey    Teaching profession
# 11      12                   Vaishali Selot    Teaching profession
# 12      13                  Dr. Bharatkumar   Medical professional
# ...

# %%
#test_df['Age_group_new'] = le_Age_group.fit_transform(test_df['Age_group'])
test_df['Designation_new'] = le_Q1.fit_transform(test_df['Designation'])
test_df['Economic_status_new'] = le_Q1.fit_transform(test_df['Economic status '])
test_df['Q1_new'] = le_Q1.fit_transform(test_df['1. Does limited insurance coverage have an impact on individuals seeking mental health services?'])
test_df['Q2_new'] = le_Q2.fit_transform(test_df['2. Do you have health insurance that covers mental health services? '])
test_df['Q3_new'] = le_Q3.fit_transform(test_df['3. Would you be more likely to use mental health services if they were covered by insurance? '])
test_df['Q4_new'] = le_Q4.fit_transform(test_df['4. Does stigma and discrimination contribute to people not availing mental health services?'])
test_df['Q5_new'] = le_Q5.fit_transform(test_df['5. Are the costs of mental health services too high for you?'])
test_df['Q6_new'] = le_Q6.fit_transform(test_df['6. Do high treatment costs have consequences on mental health services?'])
test_df['Q7_new'] = le_Q7.fit_transform(test_df['7. Does inadequate government funding impact mental health services?'])
test_df['Q8_new'] = le_Q8.fit_transform(test_df['8. Do workplace barriers contribute to the economic burden in mental health services?'])
test_df['Q9_new'] = le_Q9.fit_transform(test_df['9. Does a shortage of mental health professionals have an impact on mental health services?'])
test_df['Q10_new'] = le_Q10.fit_transform(test_df['10. Do you think increasing the number of mental health professionals in your area would improve access?  '])
test_df['Q11_new'] = le_Q11.fit_transform(test_df['11. Do geographical disparities affect the economic burden in mental health services?'])
test_df['Q12_new'] = le_Q12.fit_transform(test_df['12. Does lack of reliable transportation affect mental health service access?'])
test_df['Q13_new'] = le_Q13.fit_transform(test_df['13. Are there consequence of the lack of early intervention programs on mental health services?'])
test_df['Q14_new'] = le_Q14.fit_transform(test_df['14. Does insufficient integration with primary care contribute to problems associated with availing mental health services?'])
test_df['Q15_new'] = le_Q15.fit_transform(test_df['15. Do challenge arises from a fragmented mental health care system?'])
test_df['Q16_new'] = le_Q16.fit_transform(test_df['16. Do you know where to find information about mental health services? '])
test_df['Q17_new'] = le_Q17.fit_transform(test_df['17. Can investments lead to better mental health outcomes?'])
test_df['Q18_new'] = le_Q18.fit_transform(test_df['18. Would public awareness campaigns about mental health reduce stigma and improve access?  '])

# %%
test_df.head()
# Out:
#    Sr No. Name of the Participant            Designation  \
# 0       1          Palwinder Singh    Corporate employee
# 1       2            Jaideep Pawar         Self-Business
# 2       3         Dr Vinita Goyle   Medical professional
# 3       4           SATISH THANAGE    Corporate employee
# 4       5             Laxmi Pawar          Self-Business
#
#                                     Economic status     Age Group   \
# 0  Upper Income households (more than 30,00,000 I...       45 - 54
# 1  Middle Income households (1,25,000-30,00,000 I...       45 - 54
# 2  Middle Income households (1,25,000-30,00,000 I...  55 and above
# 3  Upper Income households (more than 30,00,000 I...       45 - 54
# 4  Upper Income households (more than 30,00,000 I...         35-44
#
#   1. Does limited insurance coverage have an impact on individuals seeking mental health services?  \
# 0                                                Yes
# 1                                           Not Sure
# ...

# %%
### STEP: Dropping unwanted columns
# dropping unwanted columns

columns_to_drop = ['Sr No.','Age Group ','Name of the Participant ','Designation', 'Economic status ', '1. Does limited insurance coverage have an impact on individuals seeking mental health services?','2. Do you have health insurance that covers mental health services? ','3. Would you be more likely to use mental health services if they were covered by insurance? ', '4. Does stigma and discrimination contribute to people not availing mental health services?', '5. Are the costs of mental health services too high for you?', '6. Do high treatment costs have consequences on mental health services?', '7. Does inadequate government funding impact mental health services?', '8. Do workplace barriers contribute to the economic burden in mental health services?', '9. Does a shortage of mental health professionals have an impact on mental health services?', '10. Do you think increasing the number of mental health professionals in your area would improve access?  ', '11. Do geographical disparities affect the economic burden in mental health services?', '12. Does lack of reliable transportation affect mental health service access?', '13. Are there consequence of the lack of early intervention programs on mental health services?', '14. Does insufficient integration with primary care contribute to problems associated with availing mental health services?', '15. Do challenge arises from a fragmented mental health care system?', '16. Do you know where to find information about mental health services? ', '17. Can investments lead to better mental health outcomes?', '18. Would public awareness campaigns about mental health reduce stigma and improve access?  ']


new_input_df = test_df.drop(columns_to_drop, axis=1)
new_input_df.head(54)
# Out:
#     Designation_new  Age_group_new  Economic_status_new  Q1_new  Q2_new  \
# 0                 0              3                    2       2       0
# 1                 4              3                    1       1       0
# 2                 2              4                    1       2       1
# 3                 0              3                    2       2       0
# 4                 4              2                    2       0       0
# 5                 0              3                    2       2       2
# 6                 3              4                    1       1       0
# 7                 5              1                    1       2       2
# 8                 3              4                    1       2       0
# 9                 4              3                    2       2       1
# 10                5              4                    1       1       0
# 11                5              2                    1       0       0
# ...

# %% [markdown]
# ### STEP : Saving the dataframe

# %%
# saving the dataframe
new_input_df.to_csv('/content/economics-eda-repo/Output-EDA-Health-Economics-EDA-CSV.csv')

# %% [markdown]
# ### STEP : Data Visualization

# %%
# Read "Complete Output CSV File"
data =  pd.read_csv("/content/economics-eda-repo/Output-EDA-Health-Economics-EDA-CSV.csv")

data.head()
# Out:
#    Unnamed: 0  Designation_new  Age_group_new  Economic_status_new  Q1_new  \
# 0           0                0              3                    2       2
# 1           1                4              3                    1       1
# 2           2                2              4                    1       2
# 3           3                0              3                    2       2
# 4           4                4              2                    2       0
#
#    Q2_new  Q3_new  Q4_new  Q5_new  Q6_new  ...  Q9_new  Q10_new  Q11_new  \
# 0       0       3       3       3       3  ...       2        3        1
# 1       0       3       3       1       3  ...       2        3        3
# 2       1       0       3       0       3  ...       2        1        1
# 3       0       2       1       1       1  ...       2        3        3
# 4       0       3       3       1       3  ...       2        1        3
#
#    Q12_new  Q13_new  Q14_new  Q15_new  Q16_new  Q17_new  Q18_new
# ...

# %% [markdown]
# #### A. Box plot:

# %%
# BOX PLOT PYTHON CODE SAMPLE -1

import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Read "Output Responses.CSV File"
data =  pd.read_csv("/content/economics-eda-repo/Output-EDA-Health-Economics-EDA-CSV.csv")

data.head(1)

# Create a DataFrame from the data
df = pd.DataFrame(data)

# Set up the figure and axes
plt.figure(figsize=(12, 8))
sns.set(style="whitegrid")

# Create the boxplot using Seaborn
sns.boxplot(data=df.iloc[:, 1:], palette="viridis")  # Assuming the numerical columns start from index 1 # DEA Correction to the appropriate name


# Customize the plot
plt.title("Distribution of Responses") # DEA Correction to the appropriate name
plt.xticks(rotation=90)
plt.xlabel("Questions")
plt.ylabel("Response Value")

# Show the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# # INSIGHTS :: Exploratory Data Analysis
# ### INSIGHT 1 : TBU::

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns



# Read the CSV file
df = pd.read_csv("/content/economics-eda-repo/Output-EDA-Health-Economics-EDA-CSV.csv")

# Check the first few rows of the dataframe
print(df.head())

# Check the columns in the dataframe
print(df.columns)

# Assuming "Q1_new" column exists, generate pie chart for its value counts
if 'Q1_new' in df.columns:
    # Count the occurrences of each value in the 'Q1_new' column
    q1_counts = df['Q1_new'].value_counts()

    # Plotting the pie chart
    fig, ax = plt.subplots(1, 2, figsize=(16, 8))



    # Pie chart
    wedges, labels, autopct = ax[0].pie(q1_counts, labels=q1_counts.index, autopct='%1.1f%%', startangle=140)
    ax[0].legend(wedges, q1_counts.index, title="TITLE", loc="upper right", bbox_to_anchor=(1, 0, 0.5, 1))
    custom_labels = [str(i) for i in range(6)]
    plt.gca().set_prop_cycle(None)  # Reset color cycle
    for i, custom_label in enumerate(custom_labels):
        plt.plot([], label=custom_label)
    ax[0].set_title('TITLE')
    ax[0].axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.



    # Count plot
    top_four_categories = q1_counts.nlargest(4).index
    sns.countplot(x='Q1_new', data=df[df['Q1_new'].isin(top_four_categories)], ax=ax[1], order=top_four_categories, palette='viridis')
    ax[1].set_title('Count of Top Three TITLE')

    plt.tight_layout()
    plt.show()
else:
    print("Column 'Q1_new' not found in the CSV file.")
# Out:
#    Unnamed: 0  Designation_new  Age_group_new  Economic_status_new  Q1_new  \
# 0           0                0              3                    2       2
# 1           1                4              3                    1       1
# 2           2                2              4                    1       2
# 3           3                0              3                    2       2
# 4           4                4              2                    2       0
#
#    Q2_new  Q3_new  Q4_new  Q5_new  Q6_new  ...  Q9_new  Q10_new  Q11_new  \
# 0       0       3       3       3       3  ...       2        3        1
# 1       0       3       3       1       3  ...       2        3        3
# 2       1       0       3       0       3  ...       2        1        1
# 3       0       2       1       1       1  ...       2        3        3
# 4       0       3       3       1       3  ...       2        1        3
#
#    Q12_new  Q13_new  Q14_new  Q15_new  Q16_new  Q17_new  Q18_new
# ...

# %% [markdown]
# #Advanced Insights :: Exploratory Data Analysis#

# %% [markdown]
# # NEW INSIGHTS

# %% [markdown]
# ==============================
#
# Likelihood of Using Services if Covered by Insurance vs. High Costs of Services
# Those who perceive the costs of mental health services as too high (Q5) are more likely to use these services if they were covered by insurance (Q3), particularly in middle-income households and among self-business professionals.
#
#
#
# ==============================

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Read the CSV file
df = pd.read_csv("/content/economics-eda-repo/Output-EDA-Health-Economics-EDA-CSV.csv")

# Check the first few rows of the dataframe
print(df.head())

# Extract the columns Q3_new and Q5_new
q3_data = df['Q3_new']
q5_data = df['Q5_new']

# Print the first few rows of these columns
print("Q3_new Data:")
print(q3_data.head())

print("\nQ5_new Data:")
print(q5_data.head())

# Perform basic analysis: count unique responses in Q3_new and Q5_new
q3_counts = q3_data.value_counts()
q5_counts = q5_data.value_counts()

print("\nQ3_new Value Counts:")
print(q3_counts)

print("\nQ5_new Value Counts:")
print(q5_counts)

# Visualization of the Q3_new responses
plt.figure(figsize=(10, 5))
sns.barplot(x=q3_counts.index, y=q3_counts.values, palette="Blues_d")
plt.title('Distribution of Responses in Q3_new')
plt.xlabel('Responses')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# Visualization of the Q5_new responses
plt.figure(figsize=(10, 5))
sns.barplot(x=q5_counts.index, y=q5_counts.values, palette="Greens_d")
plt.title('Distribution of Responses in Q5_new')
plt.xlabel('Responses')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()
# Out:
#    Unnamed: 0  Designation_new  Age_group_new  Economic_status_new  Q1_new  \
# 0           0                0              3                    2       2
# 1           1                4              3                    1       1
# 2           2                2              4                    1       2
# 3           3                0              3                    2       2
# 4           4                4              2                    2       0
#
#    Q2_new  Q3_new  Q4_new  Q5_new  Q6_new  ...  Q9_new  Q10_new  Q11_new  \
# 0       0       3       3       3       3  ...       2        3        1
# 1       0       3       3       1       3  ...       2        3        3
# 2       1       0       3       0       3  ...       2        1        1
# 3       0       2       1       1       1  ...       2        3        3
# 4       0       3       3       1       3  ...       2        1        3
#
#    Q12_new  Q13_new  Q14_new  Q15_new  Q16_new  Q17_new  Q18_new
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Read the CSV file
df = pd.read_csv("/content/economics-eda-repo/Output-EDA-Health-Economics-EDA-CSV.csv")

# Check the first few rows of the dataframe
print(df.head())

# Extract the columns Q3_new and Q5_new
q3_data = df['Q3_new']
q5_data = df['Q5_new']

# Print the first few rows of these columns
print("Q3_new Data:")
print(q3_data.head())

print("\nQ5_new Data:")
print(q5_data.head())

# Perform basic analysis: count unique responses in Q3_new and Q5_new (absolute counts)
q3_absolute_counts = q3_data.value_counts()
q5_absolute_counts = q5_data.value_counts()

# Perform analysis: calculate percentage counts in Q3_new and Q5_new (percentage counts)
q3_percentage_counts = q3_data.value_counts(normalize=True) * 100
q5_percentage_counts = q5_data.value_counts(normalize=True) * 100

# Print absolute counts for Q3_new
print("\nQ3_new Absolute Value Counts:")
print(q3_absolute_counts)

# Print percentage counts for Q3_new
print("\nQ3_new Percentage Value Counts:")
print(q3_percentage_counts)

# Print absolute counts for Q5_new
print("\nQ5_new Absolute Value Counts:")
print(q5_absolute_counts)

# Print percentage counts for Q5_new
print("\nQ5_new Percentage Value Counts:")
print(q5_percentage_counts)
# Out:
#    Unnamed: 0  Designation_new  Age_group_new  Economic_status_new  Q1_new  \
# 0           0                0              3                    2       2
# 1           1                4              3                    1       1
# 2           2                2              4                    1       2
# 3           3                0              3                    2       2
# 4           4                4              2                    2       0
#
#    Q2_new  Q3_new  Q4_new  Q5_new  Q6_new  ...  Q9_new  Q10_new  Q11_new  \
# 0       0       3       3       3       3  ...       2        3        1
# 1       0       3       3       1       3  ...       2        3        3
# 2       1       0       3       0       3  ...       2        1        1
# 3       0       2       1       1       1  ...       2        3        3
# 4       0       3       3       1       3  ...       2        1        3
#
#    Q12_new  Q13_new  Q14_new  Q15_new  Q16_new  Q17_new  Q18_new
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Read the CSV file
df = pd.read_csv("/content/economics-eda-repo/Output-EDA-Health-Economics-EDA-CSV.csv")

# Check the first few rows of the dataframe
print(df.head())

# Check the columns in the dataframe
print(df.columns)

# Assuming "Q5_new" and "Q3_new" columns exist
if 'Q5_new' in df.columns and 'Q3_new' in df.columns:
    # Set the figure size
    plt.figure(figsize=(20, 12))

    # Create the countplot
    ax = sns.countplot(x="Q5_new", hue="Q3_new", data=df, palette='viridis')
    plt.title("Likelihood of Using Services if Covered by Insurance vs. High Costs of Services")
    plt.xlabel("Likelihood of Using Services if Covered by Insurance")
    plt.ylabel("High Costs of Services Count")
    plt.legend(title="High Costs of Services")

    # Display count values along with x-axis categories and y-axis counts
    for p in ax.patches:
        height = p.get_height()  # y-axis value (count)
        x_value = p.get_x() + p.get_width() / 2.  # Position for x
        x_category = p.get_x() + p.get_width() / 2.  # Position for x label

        # Extract the x-axis category label
        x_tick_label = ax.get_xticklabels()[int(x_value)].get_text()

        # Annotate with x-axis label, y-axis label, and the respective values
        ax.annotate(f'Likelihood: {x_tick_label}\nCount: {height}', (x_value, height),
                    ha='center', va='center', fontsize=12, color='black', xytext=(0, 10),
                    textcoords='offset points')

    plt.tight_layout()
    plt.show()
else:
    print("Columns 'Q5_new' and/or 'Q3_new' not found in the CSV file.")
# Out:
#    Unnamed: 0  Designation_new  Age_group_new  Economic_status_new  Q1_new  \
# 0           0                0              3                    2       2
# 1           1                4              3                    1       1
# 2           2                2              4                    1       2
# 3           3                0              3                    2       2
# 4           4                4              2                    2       0
#
#    Q2_new  Q3_new  Q4_new  Q5_new  Q6_new  ...  Q9_new  Q10_new  Q11_new  \
# 0       0       3       3       3       3  ...       2        3        1
# 1       0       3       3       1       3  ...       2        3        3
# 2       1       0       3       0       3  ...       2        1        1
# 3       0       2       1       1       1  ...       2        3        3
# 4       0       3       3       1       3  ...       2        1        3
#
#    Q12_new  Q13_new  Q14_new  Q15_new  Q16_new  Q17_new  Q18_new
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Read the CSV file
df = pd.read_csv("/content/economics-eda-repo/Output-EDA-Health-Economics-EDA-CSV.csv")

# Check the first few rows of the dataframe
print(df.head())

# Check the columns in the dataframe
print(df.columns)

# Assuming "Q5_new" 5. Are the costs of mental health services too high for you?   and "Q3_new"  3. Would you be more likely to use mental health services if they were covered by insurance?  columns exist
if 'Q5_new' in df.columns and 'Q3_new' in df.columns:
    # Likelihood of Using Services if Covered by Insurance vs. High Costs of Services
    plt.figure(figsize=(20, 12))

    # Likelihood of Using Services if Covered by Insurance vs. High Costs of Services
    sns.countplot(x="Q5_new",hue="Q3_new", data=df, palette='viridis')
    plt.title("Likelihood of Using Services if Covered by Insurance vs. High Costs of Services")
    plt.xlabel("Likelihood of Using Services if Covered by Insurance")
    plt.ylabel("High Costs of Services Count")
    plt.legend(title="High Costs of Services")

    plt.tight_layout()
    plt.show()
else:
    print("Columns 'Q5_new' and/or 'Q3_new' not found in the CSV file.")
# Out:
#    Unnamed: 0  Designation_new  Age_group_new  Economic_status_new  Q1_new  \
# 0           0                0              3                    2       2
# 1           1                4              3                    1       1
# 2           2                2              4                    1       2
# 3           3                0              3                    2       2
# 4           4                4              2                    2       0
#
#    Q2_new  Q3_new  Q4_new  Q5_new  Q6_new  ...  Q9_new  Q10_new  Q11_new  \
# 0       0       3       3       3       3  ...       2        3        1
# 1       0       3       3       1       3  ...       2        3        3
# 2       1       0       3       0       3  ...       2        1        1
# 3       0       2       1       1       1  ...       2        3        3
# 4       0       3       3       1       3  ...       2        1        3
#
#    Q12_new  Q13_new  Q14_new  Q15_new  Q16_new  Q17_new  Q18_new
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Read the CSV file
df = pd.read_csv("/content/economics-eda-repo/Output-EDA-Health-Economics-EDA-CSV.csv")

# Check the first few rows of the dataframe
print(df.head())

# Check the columns in the dataframe
print(df.columns)

# Assuming "Q5_new" and "Q3_new" columns exist
if 'Q5_new' in df.columns and 'Q3_new' in df.columns:
    # Set the figure size
    plt.figure(figsize=(20, 12))

    # Create the countplot with interchanged x and y axes
    ax = sns.countplot(x="Q3_new", hue="Q5_new", data=df, palette='viridis')
    plt.title("High Costs of Services vs. Likelihood of Using Services if Covered by Insurance")
    plt.xlabel("High Costs of Services")
    plt.ylabel("Likelihood of Using Services Count")
    plt.legend(title="Likelihood of Using Services")

    # Display count values along with x-axis categories and y-axis counts
    for p in ax.patches:
        height = p.get_height()  # y-axis value (count)
        x_value = p.get_x() + p.get_width() / 2.  # Position for x

        # Extract the x-axis category label
        x_tick_label = ax.get_xticklabels()[int(x_value)].get_text()

        # Annotate with x-axis label, y-axis label, and the respective values
        ax.annotate(f'Costs: {x_tick_label}\nCount: {height}', (x_value, height),
                    ha='center', va='center', fontsize=12, color='black', xytext=(0, 10),
                    textcoords='offset points')

    plt.tight_layout()
    plt.show()
else:
    print("Columns 'Q5_new' and/or 'Q3_new' not found in the CSV file.")
# Out:
#    Unnamed: 0  Designation_new  Age_group_new  Economic_status_new  Q1_new  \
# 0           0                0              3                    2       2
# 1           1                4              3                    1       1
# 2           2                2              4                    1       2
# 3           3                0              3                    2       2
# 4           4                4              2                    2       0
#
#    Q2_new  Q3_new  Q4_new  Q5_new  Q6_new  ...  Q9_new  Q10_new  Q11_new  \
# 0       0       3       3       3       3  ...       2        3        1
# 1       0       3       3       1       3  ...       2        3        3
# 2       1       0       3       0       3  ...       2        1        1
# 3       0       2       1       1       1  ...       2        3        3
# 4       0       3       3       1       3  ...       2        1        3
#
#    Q12_new  Q13_new  Q14_new  Q15_new  Q16_new  Q17_new  Q18_new
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Read the CSV file
df = pd.read_csv("/content/economics-eda-repo/Output-EDA-Health-Economics-EDA-CSV.csv")

# Check the first few rows of the dataframe
print(df.head())

# Check the columns in the dataframe
print(df.columns)

# Assuming "Q5_new" and "Q3_new" columns exist
if 'Q5_new' in df.columns and 'Q3_new' in df.columns:
    # Set the figure size
    plt.figure(figsize=(20, 12))

    # Create the countplot with interchanged y and x axes
    ax = sns.countplot(y="Q3_new", hue="Q5_new", data=df, palette='viridis')
    plt.title("High Costs of Services vs. Likelihood of Using Services if Covered by Insurance")
    plt.ylabel("High Costs of Services")
    plt.xlabel("Likelihood of Using Services Count")
    plt.legend(title="Likelihood of Using Services")

    # Display count values along with y-axis categories and x-axis counts
    for p in ax.patches:
        width = p.get_width()  # x-axis value (count)
        y_value = p.get_y() + p.get_height() / 2.  # Position for y

        # Extract the y-axis category label
        y_tick_label = ax.get_yticklabels()[int(y_value)].get_text()

        # Annotate with y-axis label, x-axis label, and the respective values
        ax.annotate(f'Costs: {y_tick_label}\nCount: {width}', (width, y_value),
                    ha='center', va='center', fontsize=12, color='black', xytext=(10, 0),
                    textcoords='offset points')

    plt.tight_layout()
    plt.show()
else:
    print("Columns 'Q5_new' and/or 'Q3_new' not found in the CSV file.")
# Out:
#    Unnamed: 0  Designation_new  Age_group_new  Economic_status_new  Q1_new  \
# 0           0                0              3                    2       2
# 1           1                4              3                    1       1
# 2           2                2              4                    1       2
# 3           3                0              3                    2       2
# 4           4                4              2                    2       0
#
#    Q2_new  Q3_new  Q4_new  Q5_new  Q6_new  ...  Q9_new  Q10_new  Q11_new  \
# 0       0       3       3       3       3  ...       2        3        1
# 1       0       3       3       1       3  ...       2        3        3
# 2       1       0       3       0       3  ...       2        1        1
# 3       0       2       1       1       1  ...       2        3        3
# 4       0       3       3       1       3  ...       2        1        3
#
#    Q12_new  Q13_new  Q14_new  Q15_new  Q16_new  Q17_new  Q18_new
# ...

# %% [markdown]
# ==============================
# # Finalized Chart
# High Treatment Costs vs. Impact of Government Funding
# Individuals who view the costs of mental health services as too high (Q5) are also more likely to believe that inadequate government funding negatively impacts these services (Q7),
#
#
#
#
# ==============================

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Read the CSV file
df = pd.read_csv("/content/economics-eda-repo/Output-EDA-Health-Economics-EDA-CSV.csv")

# Check the first few rows of the dataframe
print(df.head())

# Check the columns in the dataframe
print(df.columns)

# Assuming "Q3_new" and "Q5_new" columns exist
if 'Q3_new' in df.columns and 'Q5_new' in df.columns:
    # Set the figure size
    plt.figure(figsize=(20, 12))

    # Create the countplot with interchanged x and y axes
    ax = sns.countplot(x="Q5_new", hue="Q3_new", data=df, palette='viridis')
    plt.title("High Costs of Services vs. Likelihood of Using Services if Covered by Insurance")
    plt.xlabel("High Costs of Services")
    plt.ylabel("Likelihood of Using Services Count")
    plt.legend(title="Likelihood of Using Services")

    # Display count values along with x-axis categories and y-axis counts
    for p in ax.patches:
        height = p.get_height()  # y-axis value (count)
        x_value = p.get_x() + p.get_width() / 2.  # Position for x

        # Extract the x-axis category label
        x_tick_label = ax.get_xticklabels()[int(x_value)].get_text()

        # Annotate with x-axis label, y-axis label, and the respective values
        ax.annotate(f'Costs: {x_tick_label}\nCount: {height}', (x_value, height),
                    ha='center', va='center', fontsize=12, color='black', xytext=(0, 10),
                    textcoords='offset points')

    plt.tight_layout()
    plt.show()
else:
    print("Columns 'Q3_new' and/or 'Q5_new' not found in the CSV file.")
# Out:
#    Unnamed: 0  Designation_new  Age_group_new  Economic_status_new  Q1_new  \
# 0           0                0              3                    2       2
# 1           1                4              3                    1       1
# 2           2                2              4                    1       2
# 3           3                0              3                    2       2
# 4           4                4              2                    2       0
#
#    Q2_new  Q3_new  Q4_new  Q5_new  Q6_new  ...  Q9_new  Q10_new  Q11_new  \
# 0       0       3       3       3       3  ...       2        3        1
# 1       0       3       3       1       3  ...       2        3        3
# 2       1       0       3       0       3  ...       2        1        1
# 3       0       2       1       1       1  ...       2        3        3
# 4       0       3       3       1       3  ...       2        1        3
#
#    Q12_new  Q13_new  Q14_new  Q15_new  Q16_new  Q17_new  Q18_new
# ...

# %% [markdown]
# 1a. Age Group vs. Limited Insurance Coverage --- 'Age_group_new' Vs 'Q1_new'

# %% [markdown]
# ==============================
#
# High Treatment Costs vs. Impact of Government Funding
# Individuals who view the costs of mental health services as too high (Q5) are also more likely to believe that inadequate government funding negatively impacts these services (Q7),
#
#
#
#
# ==============================

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Read the CSV file
df = pd.read_csv("/content/economics-eda-repo/Output-EDA-Health-Economics-EDA-CSV.csv")

# Check the first few rows of the dataframe
print(df.head())

# Check the columns in the dataframe
print(df.columns)

# Assuming "Q5_new" 5. Are the costs of mental health services too high for you?   and "Q7_new"  7. Does inadequate government funding impact mental health services?  columns exist
if 'Q5_new' in df.columns and 'Q7_new' in df.columns:
    # High Treatment Costs vs. Impact of Government Funding
    plt.figure(figsize=(20, 12))

    # High Treatment Costs vs. Impact of Government Funding
    sns.countplot(x="Q5_new",hue="Q7_new", data=df, palette='viridis')
    plt.title("High Treatment Costs vs. Impact of Government Funding")
    plt.xlabel("High Treatment Costs")
    plt.ylabel("Impact of Government Funding Count")
    plt.legend(title="Impact of Government Funding")

    plt.tight_layout()
    plt.show()
else:
    print("Columns 'Q5_new' and/or 'Q7_new' not found in the CSV file.")
# Out:
#    Unnamed: 0  Designation_new  Age_group_new  Economic_status_new  Q1_new  \
# 0           0                0              3                    2       2
# 1           1                4              3                    1       1
# 2           2                2              4                    1       2
# 3           3                0              3                    2       2
# 4           4                4              2                    2       0
#
#    Q2_new  Q3_new  Q4_new  Q5_new  Q6_new  ...  Q9_new  Q10_new  Q11_new  \
# 0       0       3       3       3       3  ...       2        3        1
# 1       0       3       3       1       3  ...       2        3        3
# 2       1       0       3       0       3  ...       2        1        1
# 3       0       2       1       1       1  ...       2        3        3
# 4       0       3       3       1       3  ...       2        1        3
#
#    Q12_new  Q13_new  Q14_new  Q15_new  Q16_new  Q17_new  Q18_new
# ...

# %% [markdown]
# ==============================
# # Finalized Chart
# High Treatment Costs vs. Impact of Government Funding
# Individuals who view the costs of mental health services as too high (Q5) are also more likely to believe that inadequate government funding negatively impacts these services (Q7),
#
#
#
#
# ==============================

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Read the CSV file
df = pd.read_csv("/content/economics-eda-repo/Output-EDA-Health-Economics-EDA-CSV.csv")

# Check the first few rows of the dataframe
print(df.head())

# Check the columns in the dataframe
print(df.columns)

# Assuming "Q5_new" 5. Are the costs of mental health services too high for you?   and "Q7_new"  7. Does inadequate government funding impact mental health
if 'Q5_new' in df.columns and 'Q7_new' in df.columns:
    # Set the figure size
    plt.figure(figsize=(20, 12))

    # Create the countplot with interchanged x and y axes
    ax = sns.countplot(x="Q7_new", hue="Q5_new", data=df, palette='viridis')
    # High Treatment Costs vs. Impact of Government Funding
    plt.title("High Treatment Costs vs. Impact of Government Funding")
    plt.xlabel("High Treatment Costs")
    plt.ylabel("Impact of Government Funding Count")
    plt.legend(title="Impact of Government Funding")

    # Display count values along with x-axis categories and y-axis counts
    for p in ax.patches:
        height = p.get_height()  # y-axis value (count)
        x_value = p.get_x() + p.get_width() / 2.  # Position for x

        # Extract the x-axis category label
        x_tick_label = ax.get_xticklabels()[int(x_value)].get_text()

        # Annotate with x-axis label, y-axis label, and the respective values
        ax.annotate(f'Costs: {x_tick_label}\nCount: {height}', (x_value, height),
                    ha='center', va='center', fontsize=12, color='black', xytext=(0, 10),
                    textcoords='offset points')

    plt.tight_layout()
    plt.show()
else:
    print("Columns 'Q5_new' and/or 'Q7_new' not found in the CSV file.")
# Out:
#    Unnamed: 0  Designation_new  Age_group_new  Economic_status_new  Q1_new  \
# 0           0                0              3                    2       2
# 1           1                4              3                    1       1
# 2           2                2              4                    1       2
# 3           3                0              3                    2       2
# 4           4                4              2                    2       0
#
#    Q2_new  Q3_new  Q4_new  Q5_new  Q6_new  ...  Q9_new  Q10_new  Q11_new  \
# 0       0       3       3       3       3  ...       2        3        1
# 1       0       3       3       1       3  ...       2        3        3
# 2       1       0       3       0       3  ...       2        1        1
# 3       0       2       1       1       1  ...       2        3        3
# 4       0       3       3       1       3  ...       2        1        3
#
#    Q12_new  Q13_new  Q14_new  Q15_new  Q16_new  Q17_new  Q18_new
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Read the CSV file
df = pd.read_csv("/content/economics-eda-repo/Output-EDA-Health-Economics-EDA-CSV.csv")

# Check the first few rows of the dataframe
print(df.head())

# Check the columns in the dataframe
print(df.columns)

# Assuming "Q7_new" 5. Are the costs of mental health services too high for you?   and "Q5_new"  7. Does inadequate government funding impact mental health
if 'Q7_new' in df.columns and 'Q5_new' in df.columns:
    # Set the figure size
    plt.figure(figsize=(20, 12))

    # Create the countplot with interchanged x and y axes
    ax = sns.countplot(x="Q5_new", hue="Q7_new", data=df, palette='viridis')
    # High Treatment Costs vs. Impact of Government Funding
    plt.title("High Treatment Costs vs. Impact of Government Funding")
    plt.xlabel("High Treatment Costs")
    plt.ylabel("Impact of Government Funding Count")
    plt.legend(title="Impact of Government Funding")

    # Display count values along with x-axis categories and y-axis counts
    for p in ax.patches:
        height = p.get_height()  # y-axis value (count)
        x_value = p.get_x() + p.get_width() / 2.  # Position for x

        # Extract the x-axis category label
        x_tick_label = ax.get_xticklabels()[int(x_value)].get_text()

        # Annotate with x-axis label, y-axis label, and the respective values
        ax.annotate(f'Costs: {x_tick_label}\nCount: {height}', (x_value, height),
                    ha='center', va='center', fontsize=12, color='black', xytext=(0, 10),
                    textcoords='offset points')

    plt.tight_layout()
    plt.show()
else:
    print("Columns 'Q7_new' and/or 'Q5_new' not found in the CSV file.")
# Out:
#    Unnamed: 0  Designation_new  Age_group_new  Economic_status_new  Q1_new  \
# 0           0                0              3                    2       2
# 1           1                4              3                    1       1
# 2           2                2              4                    1       2
# 3           3                0              3                    2       2
# 4           4                4              2                    2       0
#
#    Q2_new  Q3_new  Q4_new  Q5_new  Q6_new  ...  Q9_new  Q10_new  Q11_new  \
# 0       0       3       3       3       3  ...       2        3        1
# 1       0       3       3       1       3  ...       2        3        3
# 2       1       0       3       0       3  ...       2        1        1
# 3       0       2       1       1       1  ...       2        3        3
# 4       0       3       3       1       3  ...       2        1        3
#
#    Q12_new  Q13_new  Q14_new  Q15_new  Q16_new  Q17_new  Q18_new
# ...

# %% [markdown]
# ==============================
#
# Geographical Disparities vs. Transportation Barriers
# Geographical disparities in mental health service availability (Q11) are closely linked with transportation barriers (Q12), particularly for lower-income households and older adults in rural areas.
#
#
#
# ==============================

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Read the CSV file
df = pd.read_csv("/content/economics-eda-repo/Output-EDA-Health-Economics-EDA-CSV.csv")

# Check the first few rows of the dataframe
print(df.head())

# Check the columns in the dataframe
print(df.columns)

# Assuming "Q11_new" 11. Do geographical disparities affect the economic burden in mental health services?   and "Q12_new"  12. Does lack of reliable transportation affect mental health service access?  columns exist
if 'Q11_new' in df.columns and 'Q12_new' in df.columns:
    # Geographical Disparities vs. Transportation Barriers
    plt.figure(figsize=(20, 12))

    # Geographical Disparities vs. Transportation Barriers
    sns.countplot(x="Q11_new",hue="Q12_new", data=df, palette='viridis')
    plt.title("Geographical Disparities vs. Transportation Barriers")
    plt.xlabel("Geographical Disparities")
    plt.ylabel("Transportation Barriers Count")
    plt.legend(title="Transportation Barriers")

    plt.tight_layout()
    plt.show()
else:
    print("Columns 'Q11_new' and/or 'Q12_new' not found in the CSV file.")
# Out:
#    Unnamed: 0  Designation_new  Age_group_new  Economic_status_new  Q1_new  \
# 0           0                0              3                    2       2
# 1           1                4              3                    1       1
# 2           2                2              4                    1       2
# 3           3                0              3                    2       2
# 4           4                4              2                    2       0
#
#    Q2_new  Q3_new  Q4_new  Q5_new  Q6_new  ...  Q9_new  Q10_new  Q11_new  \
# 0       0       3       3       3       3  ...       2        3        1
# 1       0       3       3       1       3  ...       2        3        3
# 2       1       0       3       0       3  ...       2        1        1
# 3       0       2       1       1       1  ...       2        3        3
# 4       0       3       3       1       3  ...       2        1        3
#
#    Q12_new  Q13_new  Q14_new  Q15_new  Q16_new  Q17_new  Q18_new
# ...

# %% [markdown]
# ==============================
# # Finalized Chart
# Geographical Disparities vs. Transportation Barriers
# Geographical disparities in mental health service availability (Q11) are closely linked with transportation barriers (Q12), particularly for lower-income households and older adults in rural areas.
#
#
#
# ==============================

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Read the CSV file
df = pd.read_csv("/content/economics-eda-repo/Output-EDA-Health-Economics-EDA-CSV.csv")

# Check the first few rows of the dataframe
print(df.head())

# Check the columns in the dataframe
print(df.columns)

# Assuming "Q11_new" and "Q12_new" columns exist
# Assuming "Q11_new" 11. Do geographical disparities affect the economic burden in mental health services?   and "Q12_new"  12. Does lack of reliable transportation affect mental health service access?  columns exist
if 'Q11_new' in df.columns and 'Q12_new' in df.columns:
    # Set the figure size
    plt.figure(figsize=(20, 12))

    # Create the countplot with interchanged x and y axes
    # Geographical Disparities vs. Transportation Barriers
    ax = sns.countplot(x="Q12_new", hue="Q11_new", data=df, palette='viridis')
    plt.title("Geographical Disparities vs. Transportation Barriers")
    plt.xlabel("Geographical Disparities")
    plt.ylabel("Geographical Disparities Count")
    plt.legend(title="Transportation Barriers")

    # Display count values along with x-axis categories and y-axis counts
    for p in ax.patches:
        height = p.get_height()  # y-axis value (count)
        x_value = p.get_x() + p.get_width() / 2.  # Position for x

        # Extract the x-axis category label
        x_tick_label = ax.get_xticklabels()[int(x_value)].get_text()

        # Annotate with x-axis label, y-axis label, and the respective values
        ax.annotate(f'Costs: {x_tick_label}\nCount: {height}', (x_value, height),
                    ha='center', va='center', fontsize=12, color='black', xytext=(0, 10),
                    textcoords='offset points')

    plt.tight_layout()
    plt.show()
else:
    print("Columns 'Q11_new' and/or 'Q12_new' not found in the CSV file.")
# Out:
#    Unnamed: 0  Designation_new  Age_group_new  Economic_status_new  Q1_new  \
# 0           0                0              3                    2       2
# 1           1                4              3                    1       1
# 2           2                2              4                    1       2
# 3           3                0              3                    2       2
# 4           4                4              2                    2       0
#
#    Q2_new  Q3_new  Q4_new  Q5_new  Q6_new  ...  Q9_new  Q10_new  Q11_new  \
# 0       0       3       3       3       3  ...       2        3        1
# 1       0       3       3       1       3  ...       2        3        3
# 2       1       0       3       0       3  ...       2        1        1
# 3       0       2       1       1       1  ...       2        3        3
# 4       0       3       3       1       3  ...       2        1        3
#
#    Q12_new  Q13_new  Q14_new  Q15_new  Q16_new  Q17_new  Q18_new
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Read the CSV file
df = pd.read_csv("/content/economics-eda-repo/Output-EDA-Health-Economics-EDA-CSV.csv")

# Check the first few rows of the dataframe
print(df.head())

# Check the columns in the dataframe
print(df.columns)

# Assuming "Q12_new" and "Q11_new" columns exist
# Assuming "Q12_new" 11. Do geographical disparities affect the economic burden in mental health services?   and "Q11_new"  12. Does lack of reliable transportation affect mental health service access?  columns exist
if 'Q12_new' in df.columns and 'Q11_new' in df.columns:
    # Set the figure size
    plt.figure(figsize=(20, 12))

    # Create the countplot with interchanged x and y axes
    # Geographical Disparities vs. Transportation Barriers
    ax = sns.countplot(x="Q11_new", hue="Q12_new", data=df, palette='viridis')
    plt.title("Geographical Disparities vs. Transportation Barriers")
    plt.xlabel("Geographical Disparities")
    plt.ylabel("Geographical Disparities Count")
    plt.legend(title="Transportation Barriers")

    # Display count values along with x-axis categories and y-axis counts
    for p in ax.patches:
        height = p.get_height()  # y-axis value (count)
        x_value = p.get_x() + p.get_width() / 2.  # Position for x

        # Extract the x-axis category label
        x_tick_label = ax.get_xticklabels()[int(x_value)].get_text()

        # Annotate with x-axis label, y-axis label, and the respective values
        ax.annotate(f'Costs: {x_tick_label}\nCount: {height}', (x_value, height),
                    ha='center', va='center', fontsize=12, color='black', xytext=(0, 10),
                    textcoords='offset points')

    plt.tight_layout()
    plt.show()
else:
    print("Columns 'Q12_new' and/or 'Q11_new' not found in the CSV file.")
# Out:
#    Unnamed: 0  Designation_new  Age_group_new  Economic_status_new  Q1_new  \
# 0           0                0              3                    2       2
# 1           1                4              3                    1       1
# 2           2                2              4                    1       2
# 3           3                0              3                    2       2
# 4           4                4              2                    2       0
#
#    Q2_new  Q3_new  Q4_new  Q5_new  Q6_new  ...  Q9_new  Q10_new  Q11_new  \
# 0       0       3       3       3       3  ...       2        3        1
# 1       0       3       3       1       3  ...       2        3        3
# 2       1       0       3       0       3  ...       2        1        1
# 3       0       2       1       1       1  ...       2        3        3
# 4       0       3       3       1       3  ...       2        1        3
#
#    Q12_new  Q13_new  Q14_new  Q15_new  Q16_new  Q17_new  Q18_new
# ...

# %% [markdown]
# ==============================
#
# Impact of Early Intervention Programs vs. Fragmented Care Systems
# The lack of early intervention programs (Q13) is more keenly felt in areas where the mental health care system is fragmented (Q15), particularly among middle-income households and teaching professionals.
#
#
# ==============================

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Read the CSV file
df = pd.read_csv("/content/economics-eda-repo/Output-EDA-Health-Economics-EDA-CSV.csv")

# Check the first few rows of the dataframe
print(df.head())

# Check the columns in the dataframe
print(df.columns)

# Assuming "Q13_new" 13. Are there consequence of the lack of early intervention programs on mental health services?   and "Q15_new"  15. Do challenge arises from a fragmented mental health care system?  columns exist
if 'Q13_new' in df.columns and 'Q15_new' in df.columns:
    # Impact of Early Intervention Programs vs. Fragmented Care Systems
    plt.figure(figsize=(20, 12))

    # Impact of Early Intervention Programs vs. Fragmented Care Systems
    sns.countplot(x="Q13_new",hue="Q15_new", data=df, palette='viridis')
    plt.title("Impact of Early Intervention Programs vs. Fragmented Care Systems")
    plt.xlabel("Impact of Early Intervention Programs")
    plt.ylabel("Fragmented Care Systems Count")
    plt.legend(title="Fragmented Care Systems")

    plt.tight_layout()
    plt.show()
else:
    print("Columns 'Q13_new' and/or 'Q15_new' not found in the CSV file.")
# Out:
#    Unnamed: 0  Designation_new  Age_group_new  Economic_status_new  Q1_new  \
# 0           0                0              3                    2       2
# 1           1                4              3                    1       1
# 2           2                2              4                    1       2
# 3           3                0              3                    2       2
# 4           4                4              2                    2       0
#
#    Q2_new  Q3_new  Q4_new  Q5_new  Q6_new  ...  Q9_new  Q10_new  Q11_new  \
# 0       0       3       3       3       3  ...       2        3        1
# 1       0       3       3       1       3  ...       2        3        3
# 2       1       0       3       0       3  ...       2        1        1
# 3       0       2       1       1       1  ...       2        3        3
# 4       0       3       3       1       3  ...       2        1        3
#
#    Q12_new  Q13_new  Q14_new  Q15_new  Q16_new  Q17_new  Q18_new
# ...

# %% [markdown]
# ==============================
# # Finalized Chart
#
# Impact of Early Intervention Programs vs. Fragmented Care Systems
# The lack of early intervention programs (Q13) is more keenly felt in areas where the mental health care system is fragmented (Q15), particularly among middle-income households and teaching professionals.
#
#
# ==============================

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Read the CSV file
df = pd.read_csv("/content/economics-eda-repo/Output-EDA-Health-Economics-EDA-CSV.csv")

# Check the first few rows of the dataframe
print(df.head())

# Check the columns in the dataframe
print(df.columns)

# Assuming "Q13_new" and "Q15_new" columns exist
# Assuming "Q13_new" 13. Are there consequence of the lack of early intervention programs on mental health services?   and "Q15_new"  15. Do challenge arises from a fragmented mental health care system?  columns exist

if 'Q13_new' in df.columns and 'Q15_new' in df.columns:
    # Set the figure size
    plt.figure(figsize=(20, 12))

    # Create the countplot with interchanged x and y axes
    # Impact of Early Intervention Programs vs. Fragmented Care Systems
    ax = sns.countplot(x="Q15_new", hue="Q13_new", data=df, palette='viridis')
    plt.title("Impact of Early Intervention Programs vs. Fragmented Care Systems")
    plt.xlabel("Impact of Early Intervention Programs")
    plt.ylabel("Impact of Early Intervention Programs Count")
    plt.legend(title="Fragmented Care Systems")

    # Display count values along with x-axis categories and y-axis counts
    for p in ax.patches:
        height = p.get_height()  # y-axis value (count)
        x_value = p.get_x() + p.get_width() / 2.  # Position for x

        # Extract the x-axis category label
        x_tick_label = ax.get_xticklabels()[int(x_value)].get_text()

        # Annotate with x-axis label, y-axis label, and the respective values
        ax.annotate(f'Costs: {x_tick_label}\nCount: {height}', (x_value, height),
                    ha='center', va='center', fontsize=12, color='black', xytext=(0, 10),
                    textcoords='offset points')

    plt.tight_layout()
    plt.show()
else:
    print("Columns 'Q13_new' and/or 'Q15_new' not found in the CSV file.")
# Out:
#    Unnamed: 0  Designation_new  Age_group_new  Economic_status_new  Q1_new  \
# 0           0                0              3                    2       2
# 1           1                4              3                    1       1
# 2           2                2              4                    1       2
# 3           3                0              3                    2       2
# 4           4                4              2                    2       0
#
#    Q2_new  Q3_new  Q4_new  Q5_new  Q6_new  ...  Q9_new  Q10_new  Q11_new  \
# 0       0       3       3       3       3  ...       2        3        1
# 1       0       3       3       1       3  ...       2        3        3
# 2       1       0       3       0       3  ...       2        1        1
# 3       0       2       1       1       1  ...       2        3        3
# 4       0       3       3       1       3  ...       2        1        3
#
#    Q12_new  Q13_new  Q14_new  Q15_new  Q16_new  Q17_new  Q18_new
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Read the CSV file
df = pd.read_csv("/content/economics-eda-repo/Output-EDA-Health-Economics-EDA-CSV.csv")

# Check the first few rows of the dataframe
print(df.head())

# Check the columns in the dataframe
print(df.columns)

# Assuming "Q15_new" and "Q13_new" columns exist
# Assuming "Q15_new" 13. Are there consequence of the lack of early intervention programs on mental health services?   and "Q13_new"  15. Do challenge arises from a fragmented mental health care system?  columns exist

if 'Q15_new' in df.columns and 'Q13_new' in df.columns:
    # Set the figure size
    plt.figure(figsize=(20, 12))

    # Create the countplot with interchanged x and y axes
    # Impact of Early Intervention Programs vs. Fragmented Care Systems
    ax = sns.countplot(x="Q13_new", hue="Q15_new", data=df, palette='viridis')
    plt.title("Impact of Early Intervention Programs vs. Fragmented Care Systems")
    plt.xlabel("Impact of Early Intervention Programs")
    plt.ylabel("Impact of Early Intervention Programs Count")
    plt.legend(title="Fragmented Care Systems")

    # Display count values along with x-axis categories and y-axis counts
    for p in ax.patches:
        height = p.get_height()  # y-axis value (count)
        x_value = p.get_x() + p.get_width() / 2.  # Position for x

        # Extract the x-axis category label
        x_tick_label = ax.get_xticklabels()[int(x_value)].get_text()

        # Annotate with x-axis label, y-axis label, and the respective values
        ax.annotate(f'Costs: {x_tick_label}\nCount: {height}', (x_value, height),
                    ha='center', va='center', fontsize=12, color='black', xytext=(0, 10),
                    textcoords='offset points')

    plt.tight_layout()
    plt.show()
else:
    print("Columns 'Q15_new' and/or 'Q13_new' not found in the CSV file.")
# Out:
#    Unnamed: 0  Designation_new  Age_group_new  Economic_status_new  Q1_new  \
# 0           0                0              3                    2       2
# 1           1                4              3                    1       1
# 2           2                2              4                    1       2
# 3           3                0              3                    2       2
# 4           4                4              2                    2       0
#
#    Q2_new  Q3_new  Q4_new  Q5_new  Q6_new  ...  Q9_new  Q10_new  Q11_new  \
# 0       0       3       3       3       3  ...       2        3        1
# 1       0       3       3       1       3  ...       2        3        3
# 2       1       0       3       0       3  ...       2        1        1
# 3       0       2       1       1       1  ...       2        3        3
# 4       0       3       3       1       3  ...       2        1        3
#
#    Q12_new  Q13_new  Q14_new  Q15_new  Q16_new  Q17_new  Q18_new
# ...

# %% [markdown]
# ==============================
#
# Government Funding vs. Professional Shortages
# Inadequate government funding (Q7) is closely correlated with the perceived shortage of mental health professionals (Q9), 9. Does a shortage of mental health professionals have an impact on mental health services?
#
#
# ==============================

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Read the CSV file
df = pd.read_csv("/content/economics-eda-repo/Output-EDA-Health-Economics-EDA-CSV.csv")

# Check the first few rows of the dataframe
print(df.head())

# Check the columns in the dataframe
print(df.columns)

# Assuming "Q7_new" 7. Does inadequate government funding impact mental health services?   and "Q9_new"  15. Do challenge arises from a fragmented mental health care system?  columns exist
if 'Q7_new' in df.columns and 'Q9_new' in df.columns:
    # Government Funding vs. Professional Shortages
    plt.figure(figsize=(20, 12))

    # Government Funding vs. Professional Shortages
    sns.countplot(x="Q7_new",hue="Q9_new", data=df, palette='viridis')
    plt.title("Government Funding vs. Professional Shortages")
    plt.xlabel("Government Funding")
    plt.ylabel("Professional Shortages Count")
    plt.legend(title="Professional Shortages")

    plt.tight_layout()
    plt.show()
else:
    print("Columns 'Q7_new' and/or 'Q9_new' not found in the CSV file.")
# Out:
#    Unnamed: 0  Designation_new  Age_group_new  Economic_status_new  Q1_new  \
# 0           0                0              3                    2       2
# 1           1                4              3                    1       1
# 2           2                2              4                    1       2
# 3           3                0              3                    2       2
# 4           4                4              2                    2       0
#
#    Q2_new  Q3_new  Q4_new  Q5_new  Q6_new  ...  Q9_new  Q10_new  Q11_new  \
# 0       0       3       3       3       3  ...       2        3        1
# 1       0       3       3       1       3  ...       2        3        3
# 2       1       0       3       0       3  ...       2        1        1
# 3       0       2       1       1       1  ...       2        3        3
# 4       0       3       3       1       3  ...       2        1        3
#
#    Q12_new  Q13_new  Q14_new  Q15_new  Q16_new  Q17_new  Q18_new
# ...

# %% [markdown]
# ==============================
# # Finalized Chart
# Government Funding vs. Professional Shortages
# Inadequate government funding (Q7) is closely correlated with the perceived shortage of mental health professionals (Q9), 9. Does a shortage of mental health professionals have an impact on mental health services?
#
#
# ==============================

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Read the CSV file
df = pd.read_csv("/content/economics-eda-repo/Output-EDA-Health-Economics-EDA-CSV.csv")

# Check the first few rows of the dataframe
print(df.head())

# Check the columns in the dataframe
print(df.columns)

# Assuming "Q7_new" and "Q9_new" columns exist
# Assuming "Q7_new" 7. Does inadequate government funding impact mental health services?   and "Q9_new"  15. Do challenge arises from a fragmented mental health care system?  columns exist
if 'Q7_new' in df.columns and 'Q9_new' in df.columns:
    # Set the figure size
    plt.figure(figsize=(20, 12))

    # Create the countplot with interchanged x and y axes
    # Government Funding vs. Professional Shortages
    ax = sns.countplot(x="Q9_new", hue="Q7_new", data=df, palette='viridis')
    plt.title("Government Funding vs. Professional Shortages")
    plt.xlabel("Government Funding")
    plt.ylabel("Government Funding Count")
    plt.legend(title="Professional Shortages")

    # Display count values along with x-axis categories and y-axis counts
    for p in ax.patches:
        height = p.get_height()  # y-axis value (count)
        x_value = p.get_x() + p.get_width() / 2.  # Position for x

        # Extract the x-axis category label
        x_tick_label = ax.get_xticklabels()[int(x_value)].get_text()

        # Annotate with x-axis label, y-axis label, and the respective values
        ax.annotate(f'Costs: {x_tick_label}\nCount: {height}', (x_value, height),
                    ha='center', va='center', fontsize=12, color='black', xytext=(0, 10),
                    textcoords='offset points')

    plt.tight_layout()
    plt.show()
else:
    print("Columns 'Q7_new' and/or 'Q9_new' not found in the CSV file.")
# Out:
#    Unnamed: 0  Designation_new  Age_group_new  Economic_status_new  Q1_new  \
# 0           0                0              3                    2       2
# 1           1                4              3                    1       1
# 2           2                2              4                    1       2
# 3           3                0              3                    2       2
# 4           4                4              2                    2       0
#
#    Q2_new  Q3_new  Q4_new  Q5_new  Q6_new  ...  Q9_new  Q10_new  Q11_new  \
# 0       0       3       3       3       3  ...       2        3        1
# 1       0       3       3       1       3  ...       2        3        3
# 2       1       0       3       0       3  ...       2        1        1
# 3       0       2       1       1       1  ...       2        3        3
# 4       0       3       3       1       3  ...       2        1        3
#
#    Q12_new  Q13_new  Q14_new  Q15_new  Q16_new  Q17_new  Q18_new
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Read the CSV file
df = pd.read_csv("/content/economics-eda-repo/Output-EDA-Health-Economics-EDA-CSV.csv")

# Check the first few rows of the dataframe
print(df.head())

# Check the columns in the dataframe
print(df.columns)

# Assuming "Q9_new" and "Q7_new" columns exist
# Assuming "Q9_new" 7. Does inadequate government funding impact mental health services?   and "Q7_new"  15. Do challenge arises from a fragmented mental health care system?  columns exist
if 'Q9_new' in df.columns and 'Q7_new' in df.columns:
    # Set the figure size
    plt.figure(figsize=(20, 12))

    # Create the countplot with interchanged x and y axes
    # Government Funding vs. Professional Shortages
    ax = sns.countplot(x="Q7_new", hue="Q9_new", data=df, palette='viridis')
    plt.title("Government Funding vs. Professional Shortages")
    plt.xlabel("Government Funding")
    plt.ylabel("Government Funding Count")
    plt.legend(title="Professional Shortages")

    # Display count values along with x-axis categories and y-axis counts
    for p in ax.patches:
        height = p.get_height()  # y-axis value (count)
        x_value = p.get_x() + p.get_width() / 2.  # Position for x

        # Extract the x-axis category label
        x_tick_label = ax.get_xticklabels()[int(x_value)].get_text()

        # Annotate with x-axis label, y-axis label, and the respective values
        ax.annotate(f'Costs: {x_tick_label}\nCount: {height}', (x_value, height),
                    ha='center', va='center', fontsize=12, color='black', xytext=(0, 10),
                    textcoords='offset points')

    plt.tight_layout()
    plt.show()
else:
    print("Columns 'Q9_new' and/or 'Q7_new' not found in the CSV file.")
# Out:
#    Unnamed: 0  Designation_new  Age_group_new  Economic_status_new  Q1_new  \
# 0           0                0              3                    2       2
# 1           1                4              3                    1       1
# 2           2                2              4                    1       2
# 3           3                0              3                    2       2
# 4           4                4              2                    2       0
#
#    Q2_new  Q3_new  Q4_new  Q5_new  Q6_new  ...  Q9_new  Q10_new  Q11_new  \
# 0       0       3       3       3       3  ...       2        3        1
# 1       0       3       3       1       3  ...       2        3        3
# 2       1       0       3       0       3  ...       2        1        1
# 3       0       2       1       1       1  ...       2        3        3
# 4       0       3       3       1       3  ...       2        1        3
#
#    Q12_new  Q13_new  Q14_new  Q15_new  Q16_new  Q17_new  Q18_new
# ...

# %% [markdown]
# ==============================
#
# Workplace Barriers vs. Government Funding
# Workplace barriers (Q8) are often cited by those who also believe that inadequate government funding is a significant issue (Q7), particularly in the medical profession and corporate sectors.
#
#
# ==============================

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Read the CSV file
df = pd.read_csv("/content/economics-eda-repo/Output-EDA-Health-Economics-EDA-CSV.csv")

# Check the first few rows of the dataframe
print(df.head())

# Check the columns in the dataframe
print(df.columns)

# Assuming "Q8_new" 8. Do workplace barriers contribute to the economic burden in mental health services?  and "Q7_new"  7. Does inadequate government funding impact mental health services?
if 'Q8_new' in df.columns and 'Q7_new' in df.columns:
    # Workplace Barriers vs. Government Funding
    plt.figure(figsize=(20, 12))

    # Workplace Barriers vs. Government Funding
    sns.countplot(x="Q8_new",hue="Q7_new", data=df, palette='viridis')
    plt.title("Workplace Barriers vs. Government Funding")
    plt.xlabel("Workplace Barriers")
    plt.ylabel("Government Funding Count")
    plt.legend(title="Government Funding")

    plt.tight_layout()
    plt.show()
else:
    print("Columns 'Q8_new' and/or 'Q7_new' not found in the CSV file.")
# Out:
#    Unnamed: 0  Designation_new  Age_group_new  Economic_status_new  Q1_new  \
# 0           0                0              3                    2       2
# 1           1                4              3                    1       1
# 2           2                2              4                    1       2
# 3           3                0              3                    2       2
# 4           4                4              2                    2       0
#
#    Q2_new  Q3_new  Q4_new  Q5_new  Q6_new  ...  Q9_new  Q10_new  Q11_new  \
# 0       0       3       3       3       3  ...       2        3        1
# 1       0       3       3       1       3  ...       2        3        3
# 2       1       0       3       0       3  ...       2        1        1
# 3       0       2       1       1       1  ...       2        3        3
# 4       0       3       3       1       3  ...       2        1        3
#
#    Q12_new  Q13_new  Q14_new  Q15_new  Q16_new  Q17_new  Q18_new
# ...

# %% [markdown]
# ==============================
# # Finalized Chart
# Workplace Barriers vs. Government Funding
# Workplace barriers (Q8) are often cited by those who also believe that inadequate government funding is a significant issue (Q7), particularly in the medical profession and corporate sectors.
#
#
# ==============================

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Read the CSV file
df = pd.read_csv("/content/economics-eda-repo/Output-EDA-Health-Economics-EDA-CSV.csv")

# Check the first few rows of the dataframe
print(df.head())

# Check the columns in the dataframe
print(df.columns)

# Assuming "Q8_new" and "Q7_new" columns exist
if 'Q8_new' in df.columns and 'Q7_new' in df.columns:
    # Set the figure size
    plt.figure(figsize=(20, 12))

    # Create the countplot with interchanged x and y axes
    # Assuming "Q8_new" 8. Do workplace barriers contribute to the economic burden in mental health services?  and "Q7_new"  7. Does inadequate government funding impact mental health services?
    ax = sns.countplot(x="Q7_new", hue="Q8_new", data=df, palette='viridis')
    plt.title("Workplace Barriers vs. Government Funding")
    plt.xlabel("Workplace Barriers")
    plt.ylabel("Workplace Barriers Count")
    plt.legend(title="Government Funding")

    # Display count values along with x-axis categories and y-axis counts
    # Workplace Barriers vs. Government Funding
    for p in ax.patches:
        height = p.get_height()  # y-axis value (count)
        x_value = p.get_x() + p.get_width() / 2.  # Position for x

        # Extract the x-axis category label
        x_tick_label = ax.get_xticklabels()[int(x_value)].get_text()

        # Annotate with x-axis label, y-axis label, and the respective values
        ax.annotate(f'Costs: {x_tick_label}\nCount: {height}', (x_value, height),
                    ha='center', va='center', fontsize=12, color='black', xytext=(0, 10),
                    textcoords='offset points')

    plt.tight_layout()
    plt.show()
else:
    print("Columns 'Q8_new' and/or 'Q7_new' not found in the CSV file.")
# Out:
#    Unnamed: 0  Designation_new  Age_group_new  Economic_status_new  Q1_new  \
# 0           0                0              3                    2       2
# 1           1                4              3                    1       1
# 2           2                2              4                    1       2
# 3           3                0              3                    2       2
# 4           4                4              2                    2       0
#
#    Q2_new  Q3_new  Q4_new  Q5_new  Q6_new  ...  Q9_new  Q10_new  Q11_new  \
# 0       0       3       3       3       3  ...       2        3        1
# 1       0       3       3       1       3  ...       2        3        3
# 2       1       0       3       0       3  ...       2        1        1
# 3       0       2       1       1       1  ...       2        3        3
# 4       0       3       3       1       3  ...       2        1        3
#
#    Q12_new  Q13_new  Q14_new  Q15_new  Q16_new  Q17_new  Q18_new
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Read the CSV file
df = pd.read_csv("/content/economics-eda-repo/Output-EDA-Health-Economics-EDA-CSV.csv")

# Check the first few rows of the dataframe
print(df.head())

# Check the columns in the dataframe
print(df.columns)

# Assuming "Q7_new" and "Q8_new" columns exist
if 'Q7_new' in df.columns and 'Q8_new' in df.columns:
    # Set the figure size
    plt.figure(figsize=(20, 12))

    # Create the countplot with interchanged x and y axes
    # Assuming "Q7_new" 8. Do workplace barriers contribute to the economic burden in mental health services?  and "Q8_new"  7. Does inadequate government funding impact mental health services?
    ax = sns.countplot(x="Q8_new", hue="Q7_new", data=df, palette='viridis')
    plt.title("Workplace Barriers vs. Government Funding")
    plt.xlabel("Workplace Barriers")
    plt.ylabel("Workplace Barriers Count")
    plt.legend(title="Government Funding")

    # Display count values along with x-axis categories and y-axis counts
    # Workplace Barriers vs. Government Funding
    for p in ax.patches:
        height = p.get_height()  # y-axis value (count)
        x_value = p.get_x() + p.get_width() / 2.  # Position for x

        # Extract the x-axis category label
        x_tick_label = ax.get_xticklabels()[int(x_value)].get_text()

        # Annotate with x-axis label, y-axis label, and the respective values
        ax.annotate(f'Costs: {x_tick_label}\nCount: {height}', (x_value, height),
                    ha='center', va='center', fontsize=12, color='black', xytext=(0, 10),
                    textcoords='offset points')

    plt.tight_layout()
    plt.show()
else:
    print("Columns 'Q7_new' and/or 'Q8_new' not found in the CSV file.")
# Out:
#    Unnamed: 0  Designation_new  Age_group_new  Economic_status_new  Q1_new  \
# 0           0                0              3                    2       2
# 1           1                4              3                    1       1
# 2           2                2              4                    1       2
# 3           3                0              3                    2       2
# 4           4                4              2                    2       0
#
#    Q2_new  Q3_new  Q4_new  Q5_new  Q6_new  ...  Q9_new  Q10_new  Q11_new  \
# 0       0       3       3       3       3  ...       2        3        1
# 1       0       3       3       1       3  ...       2        3        3
# 2       1       0       3       0       3  ...       2        1        1
# 3       0       2       1       1       1  ...       2        3        3
# 4       0       3       3       1       3  ...       2        1        3
#
#    Q12_new  Q13_new  Q14_new  Q15_new  Q16_new  Q17_new  Q18_new
# ...

# %% [markdown]
# ==============================
#
# Geographical Disparities vs. Fragmented Care Systems
# Individuals who experience geographical disparities in accessing mental health services (Q11) also report significant challenges arising from a fragmented mental health care system (Q15), especially among lower-income households.
#
#
# ==============================

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Read the CSV file
df = pd.read_csv("/content/economics-eda-repo/Output-EDA-Health-Economics-EDA-CSV.csv")

# Check the first few rows of the dataframe
print(df.head())

# Check the columns in the dataframe
print(df.columns)

# Assuming "Q11_new" 11. Do geographical disparities affect the economic burden in mental health services?  and "Q15_new"  15. Do challenge arises from a fragmented mental health care system?
if 'Q11_new' in df.columns and 'Q15_new' in df.columns:
    # Geographical Disparities vs. Fragmented Care Systems
    plt.figure(figsize=(20, 12))

    # Geographical Disparities vs. Fragmented Care Systems
    sns.countplot(x="Q11_new",hue="Q15_new", data=df, palette='viridis')
    plt.title("Geographical Disparities vs. Fragmented Care Systems")
    plt.xlabel("Geographical Disparities")
    plt.ylabel("Fragmented Care Systems Count")
    plt.legend(title="Fragmented Care Systems")

    plt.tight_layout()
    plt.show()
else:
    print("Columns 'Q11_new' and/or 'Q15_new' not found in the CSV file.")
# Out:
#    Unnamed: 0  Designation_new  Age_group_new  Economic_status_new  Q1_new  \
# 0           0                0              3                    2       2
# 1           1                4              3                    1       1
# 2           2                2              4                    1       2
# 3           3                0              3                    2       2
# 4           4                4              2                    2       0
#
#    Q2_new  Q3_new  Q4_new  Q5_new  Q6_new  ...  Q9_new  Q10_new  Q11_new  \
# 0       0       3       3       3       3  ...       2        3        1
# 1       0       3       3       1       3  ...       2        3        3
# 2       1       0       3       0       3  ...       2        1        1
# 3       0       2       1       1       1  ...       2        3        3
# 4       0       3       3       1       3  ...       2        1        3
#
#    Q12_new  Q13_new  Q14_new  Q15_new  Q16_new  Q17_new  Q18_new
# ...

# %% [markdown]
# ==============================
# #### Finalized Chart
# Geographical Disparities vs. Fragmented Care Systems
# Individuals who experience geographical disparities in accessing mental health services (Q11) also report significant challenges arising from a fragmented mental health care system (Q15), especially among lower-income households.
#
#
# ==============================

# %% [markdown]
# ==============================
#
# Insurance Coverage vs. Consequences of Fragmented Care Systems
#
# Individuals with limited insurance coverage (Q1) are more likely to report problems associated with a fragmented mental health care system (Q15), especially in lower-income and middle-aged groups.
#
#
# ==============================

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Read the CSV file
df = pd.read_csv("/content/economics-eda-repo/Output-Health-Economics-EDA-CSV.csv")

# Check the first few rows of the dataframe
print(df.head())

# Check the columns in the dataframe
print(df.columns)

# Assuming "Q1_new" 1. Does limited insurance coverage have an impact on individuals seeking mental health services?  and "Q15_new"  15. Do challenge arises from a fragmented mental health care system?
if 'Q1_new' in df.columns and 'Q15_new' in df.columns:
    # Insurance Coverage vs. Consequences of Fragmented Care Systems
    plt.figure(figsize=(20, 12))

    # Insurance Coverage vs. Consequences of Fragmented Care Systems
    sns.countplot(x="Q1_new",hue="Q15_new", data=df, palette='viridis')
    plt.title("Insurance Coverage vs. Consequences of Fragmented Care Systems")
    plt.xlabel("Insurance Coverage")
    plt.ylabel("Consequences of Fragmented Care Systems Count")
    plt.legend(title="Consequences of Fragmented Care Systems")

    plt.tight_layout()
    plt.show()
else:
    print("Columns 'Q1_new' and/or 'Q15_new' not found in the CSV file.")
# Out:
#    Unnamed: 0  Designation_new  Q1_new  Q2_new  Q3_new  Q4_new  Q5_new  \
# 0           0                2       1       3       3       2       2
# 1           1                1       2       3       2       3       0
# 2           2                0       0       3       0       2       1
# 3           3                4       2       1       0       1       1
# 4           4                3       0       2       0       0       3
#
#    Q6_new  Q7_new  Q8_new  ...  Q12_new  Q13_new  Q14_new  Q15_new  Q16_new  \
# 0       2       0       3  ...        1        0        1        1        0
# 1       2       1       0  ...        2        0        3        3        2
# 2       1       2       0  ...        2        2        2        0        2
# 3       1       2       0  ...        3        3        0        2        1
# 4       3       1       0  ...        1        0        0        1        0
#
#    Q17_new  Q18_new  Q19_new  Q20_new  Age_group_new
# ...

# %% [markdown]
# ==============================
#
# Impact of Professional Shortages vs. Awareness of Services
# The shortage of mental health professionals (Q9) is closely linked to lower awareness of where to find mental health services (Q16), particularly in lower-income households and among older adults.
#
#
# ==============================

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Read the CSV file
df = pd.read_csv("/content/economics-eda-repo/Output-Health-Economics-EDA-CSV.csv")

# Check the first few rows of the dataframe
print(df.head())

# Check the columns in the dataframe
print(df.columns)

# Assuming "Q9_new" 9. Does a shortage of mental health professionals have an impact on mental health services?  and "Q16_new"  16. Do you know where to find information about mental health services?
if 'Q9_new' in df.columns and 'Q16_new' in df.columns:
    # Impact of Professional Shortages vs. Awareness of Services
    plt.figure(figsize=(20, 12))

    # Impact of Professional Shortages vs. Awareness of Services
    sns.countplot(x="Q9_new",hue="Q16_new", data=df, palette='viridis')
    plt.title("Impact of Professional Shortages vs. Awareness of Services")
    plt.xlabel("Impact of Professional Shortages")
    plt.ylabel("Awareness of Services Count")
    plt.legend(title="Awareness of Services")

    plt.tight_layout()
    plt.show()
else:
    print("Columns 'Q9_new' and/or 'Q16_new' not found in the CSV file.")
# Out:
#    Unnamed: 0  Designation_new  Q1_new  Q2_new  Q3_new  Q4_new  Q5_new  \
# 0           0                2       1       3       3       2       2
# 1           1                1       2       3       2       3       0
# 2           2                0       0       3       0       2       1
# 3           3                4       2       1       0       1       1
# 4           4                3       0       2       0       0       3
#
#    Q6_new  Q7_new  Q8_new  ...  Q12_new  Q13_new  Q14_new  Q15_new  Q16_new  \
# 0       2       0       3  ...        1        0        1        1        0
# 1       2       1       0  ...        2        0        3        3        2
# 2       1       2       0  ...        2        2        2        0        2
# 3       1       2       0  ...        3        3        0        2        1
# 4       3       1       0  ...        1        0        0        1        0
#
#    Q17_new  Q18_new  Q19_new  Q20_new  Age_group_new
# ...

# %% [markdown]
# ==============================
#
# Government Funding vs. Fragmentation of Care Systems
# Inadequate government funding (Q7) is more frequently cited by those who also experience challenges from a fragmented mental health care system (Q15), especially among self-business professionals and lower-income households.
#
#
# ==============================

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Read the CSV file
df = pd.read_csv("/content/economics-eda-repo/Output-Health-Economics-EDA-CSV.csv")

# Check the first few rows of the dataframe
print(df.head())

# Check the columns in the dataframe
print(df.columns)

# Assuming "Q7_new" 7. Does inadequate government funding impact mental health services?  and "Q15_new"  15. Do challenge arises from a fragmented mental health care system?
if 'Q7_new' in df.columns and 'Q15_new' in df.columns:
    # Government Funding vs. Fragmentation of Care Systems
    plt.figure(figsize=(20, 12))

    # Government Funding vs. Fragmentation of Care Systems
    sns.countplot(x="Q7_new",hue="Q15_new", data=df, palette='viridis')
    plt.title("Government Funding vs. Fragmentation of Care Systems")
    plt.xlabel("Government Funding")
    plt.ylabel("Fragmentation of Care Systems Count")
    plt.legend(title="Fragmentation of Care Systems")

    plt.tight_layout()
    plt.show()
else:
    print("Columns 'Q7_new' and/or 'Q15_new' not found in the CSV file.")
# Out:
#    Unnamed: 0  Designation_new  Q1_new  Q2_new  Q3_new  Q4_new  Q5_new  \
# 0           0                2       1       3       3       2       2
# 1           1                1       2       3       2       3       0
# 2           2                0       0       3       0       2       1
# 3           3                4       2       1       0       1       1
# 4           4                3       0       2       0       0       3
#
#    Q6_new  Q7_new  Q8_new  ...  Q12_new  Q13_new  Q14_new  Q15_new  Q16_new  \
# 0       2       0       3  ...        1        0        1        1        0
# 1       2       1       0  ...        2        0        3        3        2
# 2       1       2       0  ...        2        2        2        0        2
# 3       1       2       0  ...        3        3        0        2        1
# 4       3       1       0  ...        1        0        0        1        0
#
#    Q17_new  Q18_new  Q19_new  Q20_new  Age_group_new
# ...

# %% [markdown]
# #NEW PAIR PLOT

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Read the CSV file
df = pd.read_csv("/content/economics-eda-repo/Output-Health-Economics-EDA-CSV.csv")

# Check the first few rows of the dataframe
print(df.head())

# Check the columns in the dataframe
print(df.columns)

# Define the columns of interest with updated descriptions
columns_of_interest = {
    #'Economic_status_new': 'Economic status ',
    'Q5_new': '5. Are the costs of mental health services too high for you?',
    'Q6_new': '6. Do high treatment costs have consequences on mental health services?',
    'Q1_new': '1. Does limited insurance coverage have an impact on individuals seeking mental health services?',
    'Q3_new': '3. Would you be more likely to use mental health services if they were covered by insurance?',
    'Q7_new': '7. Does inadequate government funding impact mental health services?'
}

# Filter the dataframe to include only the relevant columns
df_filtered = df[list(columns_of_interest.keys())]

# Generate the pair plot with 'viridis' palette
plt.figure(figsize=(15, 10))
pair_plot = sns.pairplot(df_filtered, palette='viridis')
plt.suptitle('Pair Plot of Selected Variables', y=1.02)  # Adjust the title position
plt.show()
# Out:
#    Unnamed: 0  Designation_new  Q1_new  Q2_new  Q3_new  Q4_new  Q5_new  \
# 0           0                2       1       3       3       2       2
# 1           1                1       2       3       2       3       0
# 2           2                0       0       3       0       2       1
# 3           3                4       2       1       0       1       1
# 4           4                3       0       2       0       0       3
#
#    Q6_new  Q7_new  Q8_new  ...  Q12_new  Q13_new  Q14_new  Q15_new  Q16_new  \
# 0       2       0       3  ...        1        0        1        1        0
# 1       2       1       0  ...        2        0        3        3        2
# 2       1       2       0  ...        2        2        2        0        2
# 3       1       2       0  ...        3        3        0        2        1
# 4       3       1       0  ...        1        0        0        1        0
#
#    Q17_new  Q18_new  Q19_new  Q20_new  Age_group_new
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Read the CSV file
df = pd.read_csv("/content/economics-eda-repo/Output-Health-Economics-EDA-CSV.csv")

# Check the first few rows of the dataframe
print(df.head())

# Check the columns in the dataframe
print(df.columns)

# Define the columns of interest with updated descriptions
columns_of_interest = {
    #'Economic_status_new': 'Economic status ',
    'Q5_new': '5. Are the costs of mental health services too high for you?',
    'Q6_new': '6. Do high treatment costs have consequences on mental health services?',
    'Q1_new': '1. Does limited insurance coverage have an impact on individuals seeking mental health services?',
    'Q3_new': '3. Would you be more likely to use mental health services if they were covered by insurance?',
    'Q7_new': '7. Does inadequate government funding impact mental health services?'
}

# Filter the dataframe to include only the relevant columns
df_filtered = df[list(columns_of_interest.keys())]

# Generate the pair plot with 'viridis' palette and line plots (KDE) on the diagonal
plt.figure(figsize=(15, 10))
pair_plot = sns.pairplot(df_filtered, palette='viridis', diag_kind='kde')
plt.suptitle('Pair Plot of Selected Variables', y=1.02)  # Adjust the title position
plt.show()
# Out:
#    Unnamed: 0  Designation_new  Q1_new  Q2_new  Q3_new  Q4_new  Q5_new  \
# 0           0                2       1       3       3       2       2
# 1           1                1       2       3       2       3       0
# 2           2                0       0       3       0       2       1
# 3           3                4       2       1       0       1       1
# 4           4                3       0       2       0       0       3
#
#    Q6_new  Q7_new  Q8_new  ...  Q12_new  Q13_new  Q14_new  Q15_new  Q16_new  \
# 0       2       0       3  ...        1        0        1        1        0
# 1       2       1       0  ...        2        0        3        3        2
# 2       1       2       0  ...        2        2        2        0        2
# 3       1       2       0  ...        3        3        0        2        1
# 4       3       1       0  ...        1        0        0        1        0
#
#    Q17_new  Q18_new  Q19_new  Q20_new  Age_group_new
# ...

# %% [markdown]
# ---------------
# ---------------

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Read the CSV file
df = pd.read_csv("/content/economics-eda-repo/Output-Health-Economics-EDA-CSV.csv")

# Check the first few rows of the dataframe
print(df.head())

# Check the columns in the dataframe
print(df.columns)

# Assuming "Age_group_new" (Age Group) and "Q1" (Limited Insurance Coverage) columns exist
if 'Age_group_new' in df.columns and 'Q1_new' in df.columns:
    # Plotting Age Group vs. Limited Insurance Coverage
    plt.figure(figsize=(20, 12))

    # Age Group vs. Limited Insurance Coverage
    sns.countplot(x="Age_group_new",hue="Q1_new", data=df, palette='viridis')
    plt.title("Age Group vs. Limited Insurance Coverage")
    plt.xlabel("Age Group")
    plt.ylabel("Limited Insurance Coverage Count")
    plt.legend(title="Limited Insurance Coverage")

    plt.tight_layout()
    plt.show()
else:
    print("Columns 'Age_group_new' (Age Group) and/or 'Q1_new' (Limited Insurance Coverage) not found in the CSV file.")
# Out:
#    Unnamed: 0  Designation_new  Q1_new  Q2_new  Q3_new  Q4_new  Q5_new  \
# 0           0                2       1       3       3       2       2
# 1           1                1       2       3       2       3       0
# 2           2                0       0       3       0       2       1
# 3           3                4       2       1       0       1       1
# 4           4                3       0       2       0       0       3
#
#    Q6_new  Q7_new  Q8_new  ...  Q12_new  Q13_new  Q14_new  Q15_new  Q16_new  \
# 0       2       0       3  ...        1        0        1        1        0
# 1       2       1       0  ...        2        0        3        3        2
# 2       1       2       0  ...        2        2        2        0        2
# 3       1       2       0  ...        3        3        0        2        1
# 4       3       1       0  ...        1        0        0        1        0
#
#    Q17_new  Q18_new  Q19_new  Q20_new  Age_group_new
# ...

# %% [markdown]
# 1b. Mental Health Related Members vs. Limited Insurance Coverage --- 'Designation_new' Vs 'Q1_new'

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Read the CSV file
df = pd.read_csv("/content/Output-Health-Economics-EDA-CSV.csv")

# Check the first few rows of the dataframe
print(df.head())

# Check the columns in the dataframe
print(df.columns)

# Assuming "Designation_new" (Mental Health Related Members) and "Q1" (Limited Insurance Coverage) columns exist
if 'Designation_new' in df.columns and 'Q1_new' in df.columns:
    # Plotting Mental Health Related Members vs. Limited Insurance Coverage
    plt.figure(figsize=(20, 12))

    # Mental Health Related Members vs. Limited Insurance Coverage
    sns.countplot(x="Designation_new",hue="Q1_new", data=df, palette='viridis')
    plt.title("Mental Health Related Members vs. Limited Insurance Coverage")
    plt.xlabel("Mental Health Related Members")
    plt.ylabel("Limited Insurance Coverage Count")
    plt.legend(title="Limited Insurance Coverage")

    plt.tight_layout()
    plt.show()
else:
    print("Columns 'Designation_new' (Mental Health Related Members) and/or 'Q1_new' (Limited Insurance Coverage) not found in the CSV file.")
# Out:
#    Unnamed: 0  Designation_new  Q1_new  Q2_new  Q3_new  Q4_new  Q5_new  \
# 0           0                2       1       3       3       2       2
# 1           1                1       2       3       2       3       0
# 2           2                0       0       3       0       2       1
# 3           3                4       2       1       0       1       1
# 4           4                3       0       2       0       0       3
#
#    Q6_new  Q7_new  Q8_new  ...  Q12_new  Q13_new  Q14_new  Q15_new  Q16_new  \
# 0       2       0       3  ...        1        0        1        1        0
# 1       2       1       0  ...        2        0        3        3        2
# 2       1       2       0  ...        2        2        2        0        2
# 3       1       2       0  ...        3        3        0        2        1
# 4       3       1       0  ...        1        0        0        1        0
#
#    Q17_new  Q18_new  Q19_new  Q20_new  Age_group_new
# ...

# %% [markdown]
# 2. Age Group vs. Stigma and Discrimination --- 'Age_Group_new' Vs 'Q2_new'

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Read the CSV file
df = pd.read_csv("/content/Output-Health-Economics-EDA-CSV.csv")

# Check the first few rows of the dataframe
print(df.head())

# Check the columns in the dataframe
print(df.columns)

# Assuming "Age_group_new" (Age Group) and "Q2" (Stigma and Discrimination) columns exist
if 'Age_group_new' in df.columns and 'Q2_new' in df.columns:
    # Plotting Age Group vs. Stigma and Discrimination
    plt.figure(figsize=(20, 12))

    # Age Group vs. Stigma and Discrimination
    sns.countplot(x="Age_group_new",hue="Q2_new", data=df, palette='viridis')
    plt.title("Age Group vs. Stigma and Discrimination")
    plt.xlabel("Age Group")
    plt.ylabel("Stigma and Discrimination Count")
    plt.legend(title="Stigma and Discrimination")

    plt.tight_layout()
    plt.show()
else:
    print("Columns 'Age_group_new' (Age Group) and/or 'Q2_new' (Stigma and Discrimination) not found in the CSV file.")
# Out:
#    Unnamed: 0  Designation_new  Q1_new  Q2_new  Q3_new  Q4_new  Q5_new  \
# 0           0                2       1       3       3       2       2
# 1           1                1       2       3       2       3       0
# 2           2                0       0       3       0       2       1
# 3           3                4       2       1       0       1       1
# 4           4                3       0       2       0       0       3
#
#    Q6_new  Q7_new  Q8_new  ...  Q12_new  Q13_new  Q14_new  Q15_new  Q16_new  \
# 0       2       0       3  ...        1        0        1        1        0
# 1       2       1       0  ...        2        0        3        3        2
# 2       1       2       0  ...        2        2        2        0        2
# 3       1       2       0  ...        3        3        0        2        1
# 4       3       1       0  ...        1        0        0        1        0
#
#    Q17_new  Q18_new  Q19_new  Q20_new  Age_group_new
# ...

# %% [markdown]
# 3. Age Group vs. High Treatment Costs --- 'Age_Group_new' Vs 'Q3_new'

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Read the CSV file
df = pd.read_csv("/content/Output-Health-Economics-EDA-CSV.csv")

# Check the first few rows of the dataframe
print(df.head())

# Check the columns in the dataframe
print(df.columns)

# Assuming "Age_group_new" (Age Group) and "Q3" (High Treatment Costs) columns exist
if 'Age_group_new' in df.columns and 'Q3_new' in df.columns:
    # Plotting Age Group vs. High Treatment Costs
    plt.figure(figsize=(20, 12))

    # Age Group vs. High Treatment Costs
    sns.countplot(x="Age_group_new",hue="Q3_new", data=df, palette='viridis')
    plt.title("Age Group vs. High Treatment Costs")
    plt.xlabel("Age Group")
    plt.ylabel("High Treatment Costs Count")
    plt.legend(title="High Treatment Costs")

    plt.tight_layout()
    plt.show()
else:
    print("Columns 'Age_group_new' (Age Group) and/or 'Q3_new' (High Treatment Costs) not found in the CSV file.")
# Out:
#    Unnamed: 0  Designation_new  Q1_new  Q2_new  Q3_new  Q4_new  Q5_new  \
# 0           0                2       1       3       3       2       2
# 1           1                1       2       3       2       3       0
# 2           2                0       0       3       0       2       1
# 3           3                4       2       1       0       1       1
# 4           4                3       0       2       0       0       3
#
#    Q6_new  Q7_new  Q8_new  ...  Q12_new  Q13_new  Q14_new  Q15_new  Q16_new  \
# 0       2       0       3  ...        1        0        1        1        0
# 1       2       1       0  ...        2        0        3        3        2
# 2       1       2       0  ...        2        2        2        0        2
# 3       1       2       0  ...        3        3        0        2        1
# 4       3       1       0  ...        1        0        0        1        0
#
#    Q17_new  Q18_new  Q19_new  Q20_new  Age_group_new
# ...

# %% [markdown]
# 4. Age Group vs. Workplace Barriers Count --- 'Age_Group_new' Vs 'Q4_new'

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Read the CSV file
df = pd.read_csv("/content/Output-Health-Economics-EDA-CSV.csv")

# Check the first few rows of the dataframe
print(df.head())

# Check the columns in the dataframe
print(df.columns)

# Assuming "Age_group_new" (Age Group) and "Q4" (Workplace Barriers) columns exist
if 'Age_group_new' in df.columns and 'Q4_new' in df.columns:
    # Plotting Age Group vs. Workplace Barriers
    plt.figure(figsize=(20, 12))

    # Age Group vs. Workplace Barriers
    sns.countplot(x="Age_group_new",hue="Q4_new", data=df, palette='viridis')
    plt.title("Age Group vs. Workplace Barriers")
    plt.xlabel("Age Group")
    plt.ylabel("Workplace Barriers Count")
    plt.legend(title="Workplace Barriers")

    plt.tight_layout()
    plt.show()
else:
    print("Columns 'Age_group_new' (Age Group) and/or 'Q4_new' (Workplace Barriers) not found in the CSV file.")
# Out:
#    Unnamed: 0  Designation_new  Q1_new  Q2_new  Q3_new  Q4_new  Q5_new  \
# 0           0                2       1       3       3       2       2
# 1           1                1       2       3       2       3       0
# 2           2                0       0       3       0       2       1
# 3           3                4       2       1       0       1       1
# 4           4                3       0       2       0       0       3
#
#    Q6_new  Q7_new  Q8_new  ...  Q12_new  Q13_new  Q14_new  Q15_new  Q16_new  \
# 0       2       0       3  ...        1        0        1        1        0
# 1       2       1       0  ...        2        0        3        3        2
# 2       1       2       0  ...        2        2        2        0        2
# 3       1       2       0  ...        3        3        0        2        1
# 4       3       1       0  ...        1        0        0        1        0
#
#    Q17_new  Q18_new  Q19_new  Q20_new  Age_group_new
# ...

# %% [markdown]
# 5. Age Group vs. Shortage of Mental Health Professionals --- 'Age_Group_new' Vs 'Q5_new'

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Read the CSV file
df = pd.read_csv("/content/Output-Health-Economics-EDA-CSV.csv")

# Check the first few rows of the dataframe
print(df.head())

# Check the columns in the dataframe
print(df.columns)

# Assuming "Age_group_new" (Age Group) and "Q5" (Shortage of Mental Health Professionals) columns exist
if 'Age_group_new' in df.columns and 'Q5_new' in df.columns:
    # Plotting Age Group vs. Shortage of Mental Health Professionals
    plt.figure(figsize=(20, 12))

    # Age Group vs. Shortage of Mental Health Professionals
    sns.countplot(x="Age_group_new",hue="Q5_new", data=df, palette='viridis')
    plt.title("Age Group vs. Shortage of Mental Health Professionals")
    plt.xlabel("Age Group")
    plt.ylabel("Shortage of Mental Health Professionals Count")
    plt.legend(title="Shortage of Mental Health Professionals")

    plt.tight_layout()
    plt.show()
else:
    print("Columns 'Age_group_new' (Age Group) and/or 'Q5_new' (Shortage of Mental Health Professionals) not found in the CSV file.")
# Out:
#    Unnamed: 0  Designation_new  Q1_new  Q2_new  Q3_new  Q4_new  Q5_new  \
# 0           0                2       1       3       3       2       2
# 1           1                1       2       3       2       3       0
# 2           2                0       0       3       0       2       1
# 3           3                4       2       1       0       1       1
# 4           4                3       0       2       0       0       3
#
#    Q6_new  Q7_new  Q8_new  ...  Q12_new  Q13_new  Q14_new  Q15_new  Q16_new  \
# 0       2       0       3  ...        1        0        1        1        0
# 1       2       1       0  ...        2        0        3        3        2
# 2       1       2       0  ...        2        2        2        0        2
# 3       1       2       0  ...        3        3        0        2        1
# 4       3       1       0  ...        1        0        0        1        0
#
#    Q17_new  Q18_new  Q19_new  Q20_new  Age_group_new
# ...

# %% [markdown]
# 6. Mental Health Related Members vs. Limited Insurance Coverage --- 'Designation_new' Vs 'Q1_new'

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Read the CSV file
df = pd.read_csv("/content/Output-Health-Economics-EDA-CSV.csv")

# Check the first few rows of the dataframe
print(df.head())

# Check the columns in the dataframe
print(df.columns)

# Assuming "Designation_new" (Mental Health Related Members) and "Q1" (Limited Insurance Coverage) columns exist
if 'Designation_new' in df.columns and 'Q1_new' in df.columns:
    # Plotting Mental Health Related Members vs. Limited Insurance Coverage
    plt.figure(figsize=(20, 12))

    # Mental Health Related Members vs. Limited Insurance Coverage
    sns.countplot(x="Designation_new",hue="Q1_new", data=df, palette='viridis')
    plt.title("Mental Health Related Members vs. Limited Insurance Coverage")
    plt.xlabel("Mental Health Related Members")
    plt.ylabel("Limited Insurance Coverage Count")
    plt.legend(title="Limited Insurance Coverage")

    plt.tight_layout()
    plt.show()
else:
    print("Columns 'Designation_new' (Mental Health Related Members) and/or 'Q1_new' (Limited Insurance Coverage) not found in the CSV file.")
# Out:
#    Unnamed: 0  Designation_new  Q1_new  Q2_new  Q3_new  Q4_new  Q5_new  \
# 0           0                2       1       3       3       2       2
# 1           1                1       2       3       2       3       0
# 2           2                0       0       3       0       2       1
# 3           3                4       2       1       0       1       1
# 4           4                3       0       2       0       0       3
#
#    Q6_new  Q7_new  Q8_new  ...  Q12_new  Q13_new  Q14_new  Q15_new  Q16_new  \
# 0       2       0       3  ...        1        0        1        1        0
# 1       2       1       0  ...        2        0        3        3        2
# 2       1       2       0  ...        2        2        2        0        2
# 3       1       2       0  ...        3        3        0        2        1
# 4       3       1       0  ...        1        0        0        1        0
#
#    Q17_new  Q18_new  Q19_new  Q20_new  Age_group_new
# ...

# %% [markdown]
# 7. Mental Health Related Members vs. Stigma and Discrimination --- 'Designation_new' Vs 'Q2_new'

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Read the CSV file
df = pd.read_csv("/content/Output-Health-Economics-EDA-CSV.csv")

# Check the first few rows of the dataframe
print(df.head())

# Check the columns in the dataframe
print(df.columns)

# Assuming "Designation_new" (Mental Health Related Members) and "Q2" (Stigma and Discrimination) columns exist
if 'Designation_new' in df.columns and 'Q2_new' in df.columns:
    # Plotting Mental Health Related Members vs. Stigma and Discrimination
    plt.figure(figsize=(20, 12))

    # Mental Health Related Members vs. Stigma and Discrimination
    sns.countplot(x="Designation_new",hue="Q2_new", data=df, palette='viridis')
    plt.title("Mental Health Related Members vs. Stigma and Discrimination")
    plt.xlabel("Mental Health Related Members")
    plt.ylabel("Stigma and Discrimination Count")
    plt.legend(title="Stigma and Discrimination")

    plt.tight_layout()
    plt.show()
else:
    print("Columns 'Designation_new' (Mental Health Related Members) and/or 'Q2_new' (Stigma and Discrimination) not found in the CSV file.")
# Out:
#    Unnamed: 0  Designation_new  Q1_new  Q2_new  Q3_new  Q4_new  Q5_new  \
# 0           0                2       1       3       3       2       2
# 1           1                1       2       3       2       3       0
# 2           2                0       0       3       0       2       1
# 3           3                4       2       1       0       1       1
# 4           4                3       0       2       0       0       3
#
#    Q6_new  Q7_new  Q8_new  ...  Q12_new  Q13_new  Q14_new  Q15_new  Q16_new  \
# 0       2       0       3  ...        1        0        1        1        0
# 1       2       1       0  ...        2        0        3        3        2
# 2       1       2       0  ...        2        2        2        0        2
# 3       1       2       0  ...        3        3        0        2        1
# 4       3       1       0  ...        1        0        0        1        0
#
#    Q17_new  Q18_new  Q19_new  Q20_new  Age_group_new
# ...

# %% [markdown]
# 8. Mental Health Related Members vs. High Treatment Costs --- 'Designation_new' Vs 'Q3_new'

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Read the CSV file
df = pd.read_csv("/content/Output-Health-Economics-EDA-CSV.csv")

# Check the first few rows of the dataframe
print(df.head())

# Check the columns in the dataframe
print(df.columns)

# Assuming "Designation_new" (Mental Health Related Members) and "Q3" (High Treatment Costs) columns exist
if 'Designation_new' in df.columns and 'Q3_new' in df.columns:
    # Plotting Mental Health Related Members vs. High Treatment Costs
    plt.figure(figsize=(20, 12))

    # Mental Health Related Members vs. High Treatment Costs
    sns.countplot(x="Designation_new",hue="Q3_new", data=df, palette='viridis')
    plt.title("Mental Health Related Members vs. High Treatment Costs")
    plt.xlabel("Mental Health Related Members")
    plt.ylabel("High Treatment Costs Count")
    plt.legend(title="High Treatment Costs")

    plt.tight_layout()
    plt.show()
else:
    print("Columns 'Designation_new' (Mental Health Related Members) and/or 'Q3_new' (High Treatment Costs) not found in the CSV file.")
# Out:
#    Unnamed: 0  Designation_new  Q1_new  Q2_new  Q3_new  Q4_new  Q5_new  \
# 0           0                2       1       3       3       2       2
# 1           1                1       2       3       2       3       0
# 2           2                0       0       3       0       2       1
# 3           3                4       2       1       0       1       1
# 4           4                3       0       2       0       0       3
#
#    Q6_new  Q7_new  Q8_new  ...  Q12_new  Q13_new  Q14_new  Q15_new  Q16_new  \
# 0       2       0       3  ...        1        0        1        1        0
# 1       2       1       0  ...        2        0        3        3        2
# 2       1       2       0  ...        2        2        2        0        2
# 3       1       2       0  ...        3        3        0        2        1
# 4       3       1       0  ...        1        0        0        1        0
#
#    Q17_new  Q18_new  Q19_new  Q20_new  Age_group_new
# ...

# %% [markdown]
# 9. Mental Health Related Members vs. Workplace Barriers --- 'Designation_new' Vs 'Q4_new'

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Read the CSV file
df = pd.read_csv("/content/Output-Health-Economics-EDA-CSV.csv")

# Check the first few rows of the dataframe
print(df.head())

# Check the columns in the dataframe
print(df.columns)

# Assuming "Designation_new" (Mental Health Related Members) and "Q4" (Workplace Barriers) columns exist
if 'Designation_new' in df.columns and 'Q4_new' in df.columns:
    # Plotting Mental Health Related Members vs. Workplace Barriers
    plt.figure(figsize=(20, 12))

    # Mental Health Related Members vs. Workplace Barriers
    sns.countplot(x="Designation_new",hue="Q4_new", data=df, palette='viridis')
    plt.title("Mental Health Related Members vs. Workplace Barriers")
    plt.xlabel("Mental Health Related Members")
    plt.ylabel("Workplace Barriers Count")
    plt.legend(title="Workplace Barriers")

    plt.tight_layout()
    plt.show()
else:
    print("Columns 'Designation_new' (Mental Health Related Members) and/or 'Q4_new' (Workplace Barriers) not found in the CSV file.")
# Out:
#    Unnamed: 0  Designation_new  Q1_new  Q2_new  Q3_new  Q4_new  Q5_new  \
# 0           0                2       1       3       3       2       2
# 1           1                1       2       3       2       3       0
# 2           2                0       0       3       0       2       1
# 3           3                4       2       1       0       1       1
# 4           4                3       0       2       0       0       3
#
#    Q6_new  Q7_new  Q8_new  ...  Q12_new  Q13_new  Q14_new  Q15_new  Q16_new  \
# 0       2       0       3  ...        1        0        1        1        0
# 1       2       1       0  ...        2        0        3        3        2
# 2       1       2       0  ...        2        2        2        0        2
# 3       1       2       0  ...        3        3        0        2        1
# 4       3       1       0  ...        1        0        0        1        0
#
#    Q17_new  Q18_new  Q19_new  Q20_new  Age_group_new
# ...

# %% [markdown]
# 10. Mental Health Related Members vs. Shortage of Mental Health Professionals --- 'Designation_new' Vs 'Q5_new'

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Read the CSV file
df = pd.read_csv("/content/Output-Health-Economics-EDA-CSV.csv")

# Check the first few rows of the dataframe
print(df.head())

# Check the columns in the dataframe
print(df.columns)

# Assuming "Designation_new" (Mental Health Related Members) and "Q5" (Shortage of Mental Health Professionals) columns exist
if 'Designation_new' in df.columns and 'Q5_new' in df.columns:
    # Plotting Mental Health Related Members vs. Shortage of Mental Health Professionals
    plt.figure(figsize=(20, 12))

    # Mental Health Related Members vs. Shortage of Mental Health Professionals
    sns.countplot(x="Designation_new",hue="Q5_new", data=df, palette='viridis')
    plt.title("Mental Health Related Members vs. Shortage of Mental Health Professionals")
    plt.xlabel("Mental Health Related Members")
    plt.ylabel("Shortage of Mental Health Professionals Count")
    plt.legend(title="Shortage of Mental Health Professionals")

    plt.tight_layout()
    plt.show()
else:
    print("Columns 'Designation_new' (Mental Health Related Members) and/or 'Q5_new' (Shortage of Mental Health Professionals) not found in the CSV file.")
# Out:
#    Unnamed: 0  Designation_new  Q1_new  Q2_new  Q3_new  Q4_new  Q5_new  \
# 0           0                2       1       3       3       2       2
# 1           1                1       2       3       2       3       0
# 2           2                0       0       3       0       2       1
# 3           3                4       2       1       0       1       1
# 4           4                3       0       2       0       0       3
#
#    Q6_new  Q7_new  Q8_new  ...  Q12_new  Q13_new  Q14_new  Q15_new  Q16_new  \
# 0       2       0       3  ...        1        0        1        1        0
# 1       2       1       0  ...        2        0        3        3        2
# 2       1       2       0  ...        2        2        2        0        2
# 3       1       2       0  ...        3        3        0        2        1
# 4       3       1       0  ...        1        0        0        1        0
#
#    Q17_new  Q18_new  Q19_new  Q20_new  Age_group_new
# ...

# %% [markdown]
# 11. Age Group vs. Mental Health Related Members --- 'Designation_new' Vs 'Age_Group_new'

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Read the CSV file
df = pd.read_csv("/content/Output-Health-Economics-EDA-CSV.csv")

# Check the first few rows of the dataframe
print(df.head())

# Check the columns in the dataframe
print(df.columns)

# Assuming "Age_group_new" (Age Group) and "Designation_new" (Mental Health Related Members) columns exist
if 'Age_group_new' in df.columns and 'Designation_new' in df.columns:
    # Plotting Age Group vs. Mental Health Related Members
    plt.figure(figsize=(10, 6))

    # Age Group vs. Limited Insurance Coverage
    sns.countplot(x="Age_group_new",hue="Designation_new", data=df, palette='viridis')
    plt.title("Age Group vs. Mental Health Related Members")
    plt.xlabel("Age Group")
    plt.ylabel("Mental Health Related Members")
    plt.legend(title="Mental Health Related Members")

    plt.tight_layout()
    plt.show()
else:
    print("Columns 'Designation_new' (Mental Health Related Members) and/or 'Q1_new' (Limited Insurance Coverage) not found in the CSV file.")
# Out:
#    Unnamed: 0  Designation_new  Q1_new  Q2_new  Q3_new  Q4_new  Q5_new  \
# 0           0                2       1       3       3       2       2
# 1           1                1       2       3       2       3       0
# 2           2                0       0       3       0       2       1
# 3           3                4       2       1       0       1       1
# 4           4                3       0       2       0       0       3
#
#    Q6_new  Q7_new  Q8_new  ...  Q12_new  Q13_new  Q14_new  Q15_new  Q16_new  \
# 0       2       0       3  ...        1        0        1        1        0
# 1       2       1       0  ...        2        0        3        3        2
# 2       1       2       0  ...        2        2        2        0        2
# 3       1       2       0  ...        3        3        0        2        1
# 4       3       1       0  ...        1        0        0        1        0
#
#    Q17_new  Q18_new  Q19_new  Q20_new  Age_group_new
# ...
